# %%
import pandas as pd 
from pprint import pprint

# %%
pd.options.display.max_colwidth=300

# %%
fifaDF=pd.read_csv("FiFA Files/fifa21_raw_data.csv", encoding="UTF-8")
# Out:
# C:\Users\colon\AppData\Local\Temp\ipykernel_12836\788314367.py:1: DtypeWarning: Columns (76) have mixed types. Specify dtype option on import or set low_memory=False.
#   fifaDF=pd.read_csv("FiFA Files/fifa21_raw_data.csv", encoding="UTF-8")

# %%
fifaDF
# Out:
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# 2      https://cdn.sofifa.com/players/200/389/21_60.png
# 3      https://cdn.sofifa.com/players/192/985/21_60.png
# 4      https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                 ...
# 18974  https://cdn.sofifa.com/players/257/710/21_60.png
# 18975  https://cdn.sofifa.com/players/258/736/21_60.png
# 18976  https://cdn.sofifa.com/players/247/223/21_60.png
# 18977  https://cdn.sofifa.com/players/258/760/21_60.png
# 18978  https://cdn.sofifa.com/players/255/958/21_60.png
#
#                            LongName  \
# 0                      Lionel Messi
# 1      C. Ronaldo dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar da Silva Santos Jr.
# ...                             ...
# ...

# %%
del fifaDF["photoUrl"]
fifaDF
# Out:
#                            LongName  \
# 0                      Lionel Messi
# 1      C. Ronaldo dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar da Silva Santos Jr.
# ...                             ...
# 18974                Mengxuan Zhang
# 18975                 Vani Da Silva
# 18976                        Ao Xia
# 18977                     Ben Hough
# 18978                  Mateo Flores
#
#                                                                 playerUrl  \
# 0                    http://sofifa.com/player/158023/lionel-messi/210005/
# 1      http://sofifa.com/player/20801/c-ronaldo-dos-santos-aveiro/210005/
# 2                       http://sofifa.com/player/200389/jan-oblak/210005/
# 3                 http://sofifa.com/player/192985/kevin-de-bruyne/210005/
# 4       http://sofifa.com/player/190871/neymar-da-silva-santos-jr/210005/
# ...                                                                   ...
# ...

# %%
#del fifaDF['Name']
#del fifaDF['playerUrl']
fifaDF
# Out:
#                            LongName  \
# 0                      Lionel Messi
# 1      C. Ronaldo dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar da Silva Santos Jr.
# ...                             ...
# 18974                Mengxuan Zhang
# 18975                 Vani Da Silva
# 18976                        Ao Xia
# 18977                     Ben Hough
# 18978                  Mateo Flores
#
#                                                                 playerUrl  \
# 0                    http://sofifa.com/player/158023/lionel-messi/210005/
# 1      http://sofifa.com/player/20801/c-ronaldo-dos-santos-aveiro/210005/
# 2                       http://sofifa.com/player/200389/jan-oblak/210005/
# 3                 http://sofifa.com/player/192985/kevin-de-bruyne/210005/
# 4       http://sofifa.com/player/190871/neymar-da-silva-santos-jr/210005/
# ...                                                                   ...
# ...

# %%
fifaDF.drop(fifaDF.iloc[:, 22:77], inplace=True, axis=1)

# %%
fifaDF
# Out:
#                            LongName  \
# 0                      Lionel Messi
# 1      C. Ronaldo dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar da Silva Santos Jr.
# ...                             ...
# 18974                Mengxuan Zhang
# 18975                 Vani Da Silva
# 18976                        Ao Xia
# 18977                     Ben Hough
# 18978                  Mateo Flores
#
#                                                                 playerUrl  \
# 0                    http://sofifa.com/player/158023/lionel-messi/210005/
# 1      http://sofifa.com/player/20801/c-ronaldo-dos-santos-aveiro/210005/
# 2                       http://sofifa.com/player/200389/jan-oblak/210005/
# 3                 http://sofifa.com/player/192985/kevin-de-bruyne/210005/
# 4       http://sofifa.com/player/190871/neymar-da-silva-santos-jr/210005/
# ...                                                                   ...
# ...

# %%
fifaDF.rename(columns={
    'LongName': 'Player Name',

}, inplace=True)

# %%
fifaDF
# Out:
#                         Player Name  \
# 0                      Lionel Messi
# 1      C. Ronaldo dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar da Silva Santos Jr.
# ...                             ...
# 18974                Mengxuan Zhang
# 18975                 Vani Da Silva
# 18976                        Ao Xia
# 18977                     Ben Hough
# 18978                  Mateo Flores
#
#                                                                 playerUrl  \
# 0                    http://sofifa.com/player/158023/lionel-messi/210005/
# 1      http://sofifa.com/player/20801/c-ronaldo-dos-santos-aveiro/210005/
# 2                       http://sofifa.com/player/200389/jan-oblak/210005/
# 3                 http://sofifa.com/player/192985/kevin-de-bruyne/210005/
# 4       http://sofifa.com/player/190871/neymar-da-silva-santos-jr/210005/
# ...                                                                   ...
# ...

# %%
fifaDF.dropna(how=("any"))
# Out:
#                      Player Name  \
# 205                  Gareth Bale
# 250    Danilo Luís Hélio Pereira
# 257              Alphonse Areola
# 299               Lucas Torreira
# 305              Matteo Politano
# ...                          ...
# 18497               Moudi Najjar
# 18569                Yubiao Deng
# 18580                Arthur Read
# 18638                    Pu Chen
# 18696               Zhechao Chen
#
#                                                                playerUrl  \
# 205                  http://sofifa.com/player/173731/gareth-bale/210005/
# 250    http://sofifa.com/player/200888/danilo-luis-helio-pereira/210005/
# 257              http://sofifa.com/player/193105/alphonse-areola/210005/
# 299               http://sofifa.com/player/223959/lucas-torreira/210005/
# 305              http://sofifa.com/player/216409/matteo-politano/210005/
# ...                                                                  ...
# ...

# %%
fifaDF.fillna({"Loan Date End":"Undisclosed"})
# Out:
#                         Player Name  \
# 0                      Lionel Messi
# 1      C. Ronaldo dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar da Silva Santos Jr.
# ...                             ...
# 18974                Mengxuan Zhang
# 18975                 Vani Da Silva
# 18976                        Ao Xia
# 18977                     Ben Hough
# 18978                  Mateo Flores
#
#                                                                 playerUrl  \
# 0                    http://sofifa.com/player/158023/lionel-messi/210005/
# 1      http://sofifa.com/player/20801/c-ronaldo-dos-santos-aveiro/210005/
# 2                       http://sofifa.com/player/200389/jan-oblak/210005/
# 3                 http://sofifa.com/player/192985/kevin-de-bruyne/210005/
# 4       http://sofifa.com/player/190871/neymar-da-silva-santos-jr/210005/
# ...                                                                   ...
# ...

# %%
fifaDF = fifaDF.to_dict('records')

# %%
from pymongo import MongoClient

# %%
mongo = MongoClient(port=27017)

# %%
db = mongo.FIFAdb
Footballers = db.Footballers

# %%
Footballers.insert_many(fifaDF)

# %%
#results = Footballers.find()

#for Footballers in results:
    #pprint(Footballers)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12836\3453720560.py in <module>
# ----> 1 results = Footballers.find()
#       2
#       3 #for Footballers in results:
#       4     #pprint(Footballers)
#
# AttributeError: 'dict' object has no attribute 'find'
