# %%
import pandas as pd

# %%
pd.options.display.max_colwidth=300

# %%
crossfitDF=pd.read_csv("women_open_21.1.csv")
crossfitDF
# Out:
#         Unnamed: 0    first_name   lastname  Placing         country  \
# 0                0     TIA-CLAIR     TOOMEY        1       Australia
# 1                1          EMMA       CARY        2   United States
# 2                2          KARA   SAUNDERS        3       Australia
# 3                3  KRISTI ERAMO  O'CONNELL        4   United States
# 4                4       MALLORY    O'BRIEN        5   United States
# ...            ...           ...        ...      ...             ...
# 108595      108595      GEORGINA    NOELLEN   108565         Germany
# 108596      108596        STACEY      MAIDA   108565   United States
# 108597      108597         FIONA      STEEL   108565  United Kingdom
# 108598      108598       RACHAEL     BUTLER   108565          Canada
# 108599      108599       VALERIA    MONTERO   108565   United States
#
#             continent     Age                        affiliate  \
# 0             Oceania  Age 27          CrossFit East Nashville
# 1       North America  Age 17  Perform Overcome Excel CrossFit
# 2             Oceania  Age 31                    CrossFit Carv
# 3       North America  Age 32                 CrossFit Polaris
# 4       North America  Age 17              Lion Brave CrossFit
# ...               ...     ...                              ...
# 108595         Europe  Age 32                   CrossFit Neuss
# 108596  North America  Age 36             CrossFit Five Points
# 108597         Europe  Age 31                              NaN
# 108598  North America  Age 34                              NaN
# 108599  North America  Age 21                              NaN
#
#        Height and Weight  points           21.1 21.1 time           21.2  \
# 0         163 cm | 58 kg      26    6th (11:21)  605 reps    11th (9:26)
# 1         64 in | 140 lb      66   14th (11:48)  605 reps     1st (8:51)
# 2        162 cm | 158 lb     111   63rd (13:11)  605 reps    23rd (9:42)
# 3         62 in | 132 lb     189  121st (13:47)  605 reps    21st (9:41)
# 4         63 in | 145 lb     211    4th (11:06)  605 reps  163rd (10:38)
# ...                  ...     ...            ...       ...            ...
# 108595    166 cm | 54 kg  374151   94308th (--)       NaN   90537th (--)
# 108596    65 in | 172 lb  374151   94308th (--)       NaN   90537th (--)
# 108597               NaN  374151   94308th (--)       NaN   90537th (--)
# 108598            130 lb  374151   94308th (--)       NaN   90537th (--)
# 108599             60 in  374151   94308th (--)       NaN   90537th (--)
#
#        21.2 time          21.3 21.3 time            21.4  \
# 0       225 reps    1st (7:37)  180 reps   8th (230 lbs)
# 1       225 reps   14th (8:28)  180 reps  37th (218 lbs)
# 2       225 reps   20th (8:41)  180 reps   5th (232 lbs)
# 3       225 reps    4th (7:47)  180 reps  43rd (217 lbs)
# 4       225 reps    2nd (7:38)  180 reps  42nd (217 lbs)
# ...          ...           ...       ...             ...
# 108595       NaN  80806th (--)       NaN   108500th (--)
# 108596       NaN  80806th (--)       NaN   108500th (--)
# 108597       NaN  80806th (--)       NaN   108500th (--)
# 108598       NaN  80806th (--)       NaN   108500th (--)
# 108599       NaN  80806th (--)       NaN   108500th (--)
#
#                          weight
# 0       Weight lifted: 230 lbs.
# 1       Weight lifted: 218 lbs.
# 2       Weight lifted: 232 lbs.
# 3       Weight lifted: 217 lbs.
# 4       Weight lifted: 217 lbs.
# ...                         ...
# 108595                      NaN
# 108596                      NaN
# 108597                      NaN
# 108598                      NaN
# 108599                      NaN
#
# [108600 rows x 18 columns]

# %%
crossfitDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108600 entries, 0 to 108599
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         108600 non-null  int64
#  1   first_name         108599 non-null  object
#  2   lastname           108597 non-null  object
#  3   Placing            108600 non-null  int64
#  4   country            108600 non-null  object
#  5   continent          108600 non-null  object
#  6   Age                108600 non-null  object
#  7   affiliate          93538 non-null   object
#  8   Height and Weight  50325 non-null   object
#  9   points             108600 non-null  int64
#  10  21.1               108600 non-null  object
#  11  21.1 time          8349 non-null    object
#  12  21.2               108600 non-null  object
#  13  21.2 time          50690 non-null   object
#  14  21.3               108600 non-null  object
#  15  21.3 time          8209 non-null    object
#  16  21.4               108600 non-null  object
#  17  weight             80318 non-null   object
# dtypes: int64(3), object(15)
# memory usage: 14.9+ MB

# %%
del crossfitDF["Unnamed: 0"]

# %%
crossfitDF.rename(columns={
    '21.1': '21.1 Scores',
    '21.2': '21.2 Scores',
    '21.3': '21.3 Scores',
    '21.4': '21.4 Scores'
}, inplace=True)

# %%
crossfitDF['first_name'] = crossfitDF['first_name'].str.title()
crossfitDF['lastname'] = crossfitDF['lastname'].str.title()

# %%
crossfitDF.head()
# Out:
#      first_name   lastname  Placing        country      continent     Age  \
# 0     Tia-Clair     Toomey        1      Australia        Oceania  Age 27
# 1          Emma       Cary        2  United States  North America  Age 17
# 2          Kara   Saunders        3      Australia        Oceania  Age 31
# 3  Kristi Eramo  O'Connell        4  United States  North America  Age 32
# 4       Mallory    O'Brien        5  United States  North America  Age 17
#
#                          affiliate Height and Weight  points    21.1 Scores  \
# 0          CrossFit East Nashville    163 cm | 58 kg      26    6th (11:21)
# 1  Perform Overcome Excel CrossFit    64 in | 140 lb      66   14th (11:48)
# 2                    CrossFit Carv   162 cm | 158 lb     111   63rd (13:11)
# 3                 CrossFit Polaris    62 in | 132 lb     189  121st (13:47)
# 4              Lion Brave CrossFit    63 in | 145 lb     211    4th (11:06)
#
#   21.1 time    21.2 Scores 21.2 time  21.3 Scores 21.3 time     21.4 Scores  \
# 0  605 reps    11th (9:26)  225 reps   1st (7:37)  180 reps   8th (230 lbs)
# 1  605 reps     1st (8:51)  225 reps  14th (8:28)  180 reps  37th (218 lbs)
# 2  605 reps    23rd (9:42)  225 reps  20th (8:41)  180 reps   5th (232 lbs)
# 3  605 reps    21st (9:41)  225 reps   4th (7:47)  180 reps  43rd (217 lbs)
# 4  605 reps  163rd (10:38)  225 reps   2nd (7:38)  180 reps  42nd (217 lbs)
#
#                     weight
# 0  Weight lifted: 230 lbs.
# 1  Weight lifted: 218 lbs.
# 2  Weight lifted: 232 lbs.
# 3  Weight lifted: 217 lbs.
# 4  Weight lifted: 217 lbs.

# %%
crossfitDF[['Height', 'Weight']] = crossfitDF['Height and Weight'].str.split("|", expand = True)
crossfitDF.head()
# Out:
#      first_name   lastname  Placing        country      continent     Age  \
# 0     Tia-Clair     Toomey        1      Australia        Oceania  Age 27
# 1          Emma       Cary        2  United States  North America  Age 17
# 2          Kara   Saunders        3      Australia        Oceania  Age 31
# 3  Kristi Eramo  O'Connell        4  United States  North America  Age 32
# 4       Mallory    O'Brien        5  United States  North America  Age 17
#
#                          affiliate Height and Weight  points    21.1 Scores  \
# 0          CrossFit East Nashville    163 cm | 58 kg      26    6th (11:21)
# 1  Perform Overcome Excel CrossFit    64 in | 140 lb      66   14th (11:48)
# 2                    CrossFit Carv   162 cm | 158 lb     111   63rd (13:11)
# 3                 CrossFit Polaris    62 in | 132 lb     189  121st (13:47)
# 4              Lion Brave CrossFit    63 in | 145 lb     211    4th (11:06)
#
#   21.1 time    21.2 Scores 21.2 time  21.3 Scores 21.3 time     21.4 Scores  \
# 0  605 reps    11th (9:26)  225 reps   1st (7:37)  180 reps   8th (230 lbs)
# 1  605 reps     1st (8:51)  225 reps  14th (8:28)  180 reps  37th (218 lbs)
# 2  605 reps    23rd (9:42)  225 reps  20th (8:41)  180 reps   5th (232 lbs)
# 3  605 reps    21st (9:41)  225 reps   4th (7:47)  180 reps  43rd (217 lbs)
# 4  605 reps  163rd (10:38)  225 reps   2nd (7:38)  180 reps  42nd (217 lbs)
#
#                     weight   Height   Weight
# 0  Weight lifted: 230 lbs.  163 cm     58 kg
# 1  Weight lifted: 218 lbs.   64 in    140 lb
# 2  Weight lifted: 232 lbs.  162 cm    158 lb
# 3  Weight lifted: 217 lbs.   62 in    132 lb
# 4  Weight lifted: 217 lbs.   63 in    145 lb

# %%
#del crossfitDF['Height and Weight']

crossfitDF.rename(columns={
    'first_name': 'First Name',
    'lastname': 'Last Name',
    'country': 'Country',
    'continent': 'Continent',
    'affiliate': 'Affiliate',
    'points': 'Points',
    '21.1 time': '21.1 Reps',
    '21.2 time': '21.2 Reps',
    '21.3 time': '21.3 Reps',
    'weight': 'Weight Lifted'
}, inplace=True)
crossfitDF.head()
# Out:
#      First Name  Last Name  Placing        Country      Continent     Age  \
# 0     Tia-Clair     Toomey        1      Australia        Oceania  Age 27
# 1          Emma       Cary        2  United States  North America  Age 17
# 2          Kara   Saunders        3      Australia        Oceania  Age 31
# 3  Kristi Eramo  O'Connell        4  United States  North America  Age 32
# 4       Mallory    O'Brien        5  United States  North America  Age 17
#
#                          Affiliate Height and Weight  Points    21.1 Scores  \
# 0          CrossFit East Nashville    163 cm | 58 kg      26    6th (11:21)
# 1  Perform Overcome Excel CrossFit    64 in | 140 lb      66   14th (11:48)
# 2                    CrossFit Carv   162 cm | 158 lb     111   63rd (13:11)
# 3                 CrossFit Polaris    62 in | 132 lb     189  121st (13:47)
# 4              Lion Brave CrossFit    63 in | 145 lb     211    4th (11:06)
#
#   21.1 Reps    21.2 Scores 21.2 Reps  21.3 Scores 21.3 Reps     21.4 Scores  \
# 0  605 reps    11th (9:26)  225 reps   1st (7:37)  180 reps   8th (230 lbs)
# 1  605 reps     1st (8:51)  225 reps  14th (8:28)  180 reps  37th (218 lbs)
# 2  605 reps    23rd (9:42)  225 reps  20th (8:41)  180 reps   5th (232 lbs)
# 3  605 reps    21st (9:41)  225 reps   4th (7:47)  180 reps  43rd (217 lbs)
# 4  605 reps  163rd (10:38)  225 reps   2nd (7:38)  180 reps  42nd (217 lbs)
#
#              Weight Lifted   Height   Weight
# 0  Weight lifted: 230 lbs.  163 cm     58 kg
# 1  Weight lifted: 218 lbs.   64 in    140 lb
# 2  Weight lifted: 232 lbs.  162 cm    158 lb
# 3  Weight lifted: 217 lbs.   62 in    132 lb
# 4  Weight lifted: 217 lbs.   63 in    145 lb

# %%
#del crossfitDF['Height and Weight']
#crossfitDF['Age'] = crossfitDF['Age'].str.replace('Age ', '')
#crossfitDF['Weight Lifted'] = crossfitDF['Weight Lifted'].str.replace('Weight lifted: ', '')
crossfitDF['21.1 Reps'] = crossfitDF['21.1 Reps'].str.replace("reps", '')
crossfitDF['21.2 Reps'] = crossfitDF['21.2 Reps'].str.replace("reps", '')
crossfitDF['21.3 Reps'] = crossfitDF['21.3 Reps'].str.replace("reps", '')
crossfitDF.head()
# Out:
#      First Name  Last Name  Placing        Country      Continent     Age  \
# 0     Tia-Clair     Toomey        1      Australia        Oceania  Age 27
# 1          Emma       Cary        2  United States  North America  Age 17
# 2          Kara   Saunders        3      Australia        Oceania  Age 31
# 3  Kristi Eramo  O'Connell        4  United States  North America  Age 32
# 4       Mallory    O'Brien        5  United States  North America  Age 17
#
#                          Affiliate Height and Weight  Points    21.1 Scores  \
# 0          CrossFit East Nashville    163 cm | 58 kg      26    6th (11:21)
# 1  Perform Overcome Excel CrossFit    64 in | 140 lb      66   14th (11:48)
# 2                    CrossFit Carv   162 cm | 158 lb     111   63rd (13:11)
# 3                 CrossFit Polaris    62 in | 132 lb     189  121st (13:47)
# 4              Lion Brave CrossFit    63 in | 145 lb     211    4th (11:06)
#
#   21.1 Reps    21.2 Scores 21.2 Reps  21.3 Scores 21.3 Reps     21.4 Scores  \
# 0      605     11th (9:26)      225    1st (7:37)      180    8th (230 lbs)
# 1      605      1st (8:51)      225   14th (8:28)      180   37th (218 lbs)
# 2      605     23rd (9:42)      225   20th (8:41)      180    5th (232 lbs)
# 3      605     21st (9:41)      225    4th (7:47)      180   43rd (217 lbs)
# 4      605   163rd (10:38)      225    2nd (7:38)      180   42nd (217 lbs)
#
#              Weight Lifted   Height   Weight
# 0  Weight lifted: 230 lbs.  163 cm     58 kg
# 1  Weight lifted: 218 lbs.   64 in    140 lb
# 2  Weight lifted: 232 lbs.  162 cm    158 lb
# 3  Weight lifted: 217 lbs.   62 in    132 lb
# 4  Weight lifted: 217 lbs.   63 in    145 lb

# %%
crossfitDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108600 entries, 0 to 108599
# Data columns (total 19 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   First Name         108599 non-null  object
#  1   Last Name          108597 non-null  object
#  2   Placing            108600 non-null  int64
#  3   Country            108600 non-null  object
#  4   Continent          108600 non-null  object
#  5   Age                108600 non-null  object
#  6   Affiliate          93538 non-null   object
#  7   Height and Weight  50325 non-null   object
#  8   Points             108600 non-null  int64
#  9   21.1 Scores        108600 non-null  object
#  10  21.1 Reps          8349 non-null    object
#  11  21.2 Scores        108600 non-null  object
#  12  21.2 Reps          50690 non-null   object
#  13  21.3 Scores        108600 non-null  object
#  14  21.3 Reps          8209 non-null    object
#  15  21.4 Scores        108600 non-null  object
#  16  Weight Lifted      80318 non-null   object
#  17  Height             50325 non-null   object
#  18  Weight             41489 non-null   object
# dtypes: int64(2), object(17)
# memory usage: 15.7+ MB

# %%
crossfitDF['Age'] = crossfitDF['Age'].str.replace("Age", '')
crossfitDF['Age'] = crossfitDF['Age'].astype(int)
crossfitDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108600 entries, 0 to 108599
# Data columns (total 19 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   First Name         108599 non-null  object
#  1   Last Name          108597 non-null  object
#  2   Placing            108600 non-null  int64
#  3   Country            108600 non-null  object
#  4   Continent          108600 non-null  object
#  5   Age                108600 non-null  int32
#  6   Affiliate          93538 non-null   object
#  7   Height and Weight  50325 non-null   object
#  8   Points             108600 non-null  int64
#  9   21.1 Scores        108600 non-null  object
#  10  21.1 Reps          8349 non-null    object
#  11  21.2 Scores        108600 non-null  object
#  12  21.2 Reps          50690 non-null   object
#  13  21.3 Scores        108600 non-null  object
#  14  21.3 Reps          8209 non-null    object
#  15  21.4 Scores        108600 non-null  object
#  16  Weight Lifted      80318 non-null   object
#  17  Height             50325 non-null   object
#  18  Weight             41489 non-null   object
# dtypes: int32(1), int64(2), object(16)
# memory usage: 15.3+ MB

# %%
crossfitDF = crossfitDF.dropna(how='any')

# %%
crossfitDF.head(10)
crossfitDF.tail(10)
# Out:
#          First Name Last Name  Placing         Country      Continent  Age  \
# 93334      Kimberly      Wong    93335          Canada  North America   32
# 93408   Mandy-Leigh   Hackart    93409       Australia        Oceania   36
# 93426     Charlotte       Cox    93427  United Kingdom         Europe   33
# 93496        Birgit   Baldauf    93497         Germany         Europe   46
# 93515      Victoria    Michel    93516   United States  North America   34
# 93906      Laetitia  Decraene    93907          France         Europe   35
# 93995         Sille  Vaiksaar    93996         Estonia         Europe   37
# 95263         Maria   Wheeler    95263   United States  North America   54
# 100420       Stella  Richards   100421   United States  North America   17
# 102709        Sarah    Carter   102710  United Kingdom         Europe   35
#
#                      Affiliate Height and Weight  Points          21.1 Scores  \
# 93334           CrossFit Green    65 in | 150 lb  338502  91409th (12:36 - f)
# 93408            CrossFit 4504    159 cm | 63 kg  338665  91515th (13:18 - f)
# 93426         CrossFit Leyland    164 cm | 66 kg  338692  91602nd (13:47 - f)
# 93496    CrossFit Rhein-Neckar    173 cm | 67 kg  338850  91588th (13:43 - f)
# 93515     CrossFit Stony Brook    69 in | 145 lb  338892   91165th (9:23 - f)
# 93906             MKB CrossFit    170 cm | 69 kg  339829  91360th (12:17 - f)
# 93995           CrossFit Tartu    174 cm | 68 kg  340095  91749th (14:32 - f)
# 95263   Wild Horizons CrossFit    63 in | 157 lb  344295  91725th (14:25 - f)
# 100420         Badger CrossFit    67 in | 140 lb  356203  91795th (14:44 - f)
# 102709            CW1 CrossFit    168 cm | 59 kg  361337  91650th (14:04 - f)
#
#        21.1 Reps          21.2 Scores 21.2 Reps          21.3 Scores  \
# 93334       605   88695th (14:05 - f)      225    78599th (9:05 - f)
# 93408       605   88575th (13:19 - f)      225    78821st (9:27 - f)
# 93426       605   88404th (12:14 - f)      225    79031st (9:51 - f)
# 93496       605   88323rd (11:41 - f)      225    79003rd (9:48 - f)
# 93515       605   88152nd (10:24 - f)      225   79945th (13:14 - f)
# 93906       605   89232nd (17:28 - f)      225   79392nd (10:40 - f)
# 93995       605   88558th (13:14 - f)      225   79979th (13:31 - f)
# 95263       605   88988th (15:49 - f)      225    79071st (9:56 - f)
# 100420      605   88760th (14:29 - f)      225    78698th (9:14 - f)
# 102709      605   88356th (11:55 - f)      225    76824th (6:45 - f)
#
#        21.3 Reps           21.4 Scores           Weight Lifted   Height  \
# 93334       180   79799th (17 lbs - f)  Weight lifted: 17 lbs.   65 in
# 93408       180   79754th (22 lbs - f)  Weight lifted: 22 lbs.  159 cm
# 93426       180   79655th (33 lbs - f)  Weight lifted: 33 lbs.  164 cm
# 93496       180    79936th (1 lbs - f)   Weight lifted: 1 lbs.  173 cm
# 93515       180   79630th (35 lbs - f)  Weight lifted: 35 lbs.   69 in
# 93906       180   79845th (13 lbs - f)  Weight lifted: 13 lbs.  170 cm
# 93995       180   79809th (16 lbs - f)  Weight lifted: 16 lbs.  174 cm
# 95263       180    84511th (0 lbs - f)   Weight lifted: 0 lbs.   63 in
# 100420      180    96950th (0 lbs - f)   Weight lifted: 0 lbs.   67 in
# 102709      180   104507th (0 lbs - f)   Weight lifted: 0 lbs.  168 cm
#
#          Weight
# 93334    150 lb
# 93408     63 kg
# 93426     66 kg
# 93496     67 kg
# 93515    145 lb
# 93906     69 kg
# 93995     68 kg
# 95263    157 lb
# 100420   140 lb
# 102709    59 kg

# %%
#crossfitDF['21.3 Reps'] = crossfitDF['21.3 Reps'].str.replace("1 front squat", '')
# ?? 
crossfitDF2 = crossfitDF[crossfitDF['21.3 Reps'].str.contains("1 front squat")==False]
crossfitDF2
# Out:
#           First Name  Last Name  Placing         Country      Continent  Age  \
# 0          Tia-Clair     Toomey        1       Australia        Oceania   27
# 1               Emma       Cary        2   United States  North America   17
# 2               Kara   Saunders        3       Australia        Oceania   31
# 3       Kristi Eramo  O'Connell        4   United States  North America   32
# 4            Mallory    O'Brien        5   United States  North America   17
# ...              ...        ...      ...             ...            ...  ...
# 93906       Laetitia   Decraene    93907          France         Europe   35
# 93995          Sille   Vaiksaar    93996         Estonia         Europe   37
# 95263          Maria    Wheeler    95263   United States  North America   54
# 100420        Stella   Richards   100421   United States  North America   17
# 102709         Sarah     Carter   102710  United Kingdom         Europe   35
#
#                               Affiliate Height and Weight  Points  \
# 0               CrossFit East Nashville    163 cm | 58 kg      26
# 1       Perform Overcome Excel CrossFit    64 in | 140 lb      66
# 2                         CrossFit Carv   162 cm | 158 lb     111
# 3                      CrossFit Polaris    62 in | 132 lb     189
# 4                   Lion Brave CrossFit    63 in | 145 lb     211
# ...                                 ...               ...     ...
# 93906                      MKB CrossFit    170 cm | 69 kg  339829
# 93995                    CrossFit Tartu    174 cm | 68 kg  340095
# 95263            Wild Horizons CrossFit    63 in | 157 lb  344295
# 100420                  Badger CrossFit    67 in | 140 lb  356203
# 102709                     CW1 CrossFit    168 cm | 59 kg  361337
#
#                 21.1 Scores 21.1 Reps          21.2 Scores 21.2 Reps  \
# 0               6th (11:21)      605           11th (9:26)      225
# 1              14th (11:48)      605            1st (8:51)      225
# 2              63rd (13:11)      605           23rd (9:42)      225
# 3             121st (13:47)      605           21st (9:41)      225
# 4               4th (11:06)      605         163rd (10:38)      225
# ...                     ...       ...                  ...       ...
# 93906   91360th (12:17 - f)      605   89232nd (17:28 - f)      225
# 93995   91749th (14:32 - f)      605   88558th (13:14 - f)      225
# 95263   91725th (14:25 - f)      605   88988th (15:49 - f)      225
# 100420  91795th (14:44 - f)      605   88760th (14:29 - f)      225
# 102709  91650th (14:04 - f)      605   88356th (11:55 - f)      225
#
#                 21.3 Scores 21.3 Reps           21.4 Scores  \
# 0                1st (7:37)      180          8th (230 lbs)
# 1               14th (8:28)      180         37th (218 lbs)
# 2               20th (8:41)      180          5th (232 lbs)
# 3                4th (7:47)      180         43rd (217 lbs)
# 4                2nd (7:38)      180         42nd (217 lbs)
# ...                     ...       ...                   ...
# 93906   79392nd (10:40 - f)      180   79845th (13 lbs - f)
# 93995   79979th (13:31 - f)      180   79809th (16 lbs - f)
# 95263    79071st (9:56 - f)      180    84511th (0 lbs - f)
# 100420   78698th (9:14 - f)      180    96950th (0 lbs - f)
# 102709   76824th (6:45 - f)      180   104507th (0 lbs - f)
#
#                   Weight Lifted   Height   Weight
# 0       Weight lifted: 230 lbs.  163 cm     58 kg
# 1       Weight lifted: 218 lbs.   64 in    140 lb
# 2       Weight lifted: 232 lbs.  162 cm    158 lb
# 3       Weight lifted: 217 lbs.   62 in    132 lb
# 4       Weight lifted: 217 lbs.   63 in    145 lb
# ...                         ...      ...      ...
# 93906    Weight lifted: 13 lbs.  170 cm     69 kg
# 93995    Weight lifted: 16 lbs.  174 cm     68 kg
# 95263     Weight lifted: 0 lbs.   63 in    157 lb
# 100420    Weight lifted: 0 lbs.   67 in    140 lb
# 102709    Weight lifted: 0 lbs.  168 cm     59 kg
#
# [491 rows x 19 columns]

# %%
test = crossfitDF['21.3 Reps']
print(test)
# Out:
# 0         180
# 1         180
# 2         180
# 3         180
# 4         180
#           ...
# 93906     180
# 93995     180
# 95263     180
# 100420    180
# 102709    180
# Name: 21.3 Reps, Length: 492, dtype: object

# %%
crossfitDF2['21.1 Reps'] = crossfitDF2['21.1 Reps'].astype(int)
crossfitDF2['21.2 Reps'] = crossfitDF2['21.2 Reps'].astype(int)
crossfitDF2['21.3 Reps'] = crossfitDF2['21.3 Reps'].astype(int)
crossfitDF2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491 entries, 0 to 102709
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         491 non-null    object
#  1   Last Name          491 non-null    object
#  2   Placing            491 non-null    int64
#  3   Country            491 non-null    object
#  4   Continent          491 non-null    object
#  5   Age                491 non-null    int32
#  6   Affiliate          491 non-null    object
#  7   Height and Weight  491 non-null    object
#  8   Points             491 non-null    int64
#  9   21.1 Scores        491 non-null    object
#  10  21.1 Reps          491 non-null    int32
#  11  21.2 Scores        491 non-null    object
#  12  21.2 Reps          491 non-null    int32
#  13  21.3 Scores        491 non-null    object
#  14  21.3 Reps          491 non-null    int32
#  15  21.4 Scores        491 non-null    object
#  16  Weight Lifted      491 non-null    object
#  17  Height             491 non-null    object
#  18  Weight             491 non-null    object
# dtypes: int32(4), int64(2), object(13)
# memory usage: 69.0+ KB
# C:\Users\User\AppData\Local\Temp\ipykernel_9456\2543708524.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crossfitDF2['21.1 Reps'] = crossfitDF2['21.1 Reps'].astype(int)
# C:\Users\User\AppData\Local\Temp\ipykernel_9456\2543708524.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crossfitDF2['21.2 Reps'] = crossfitDF2['21.2 Reps'].astype(int)
# C:\Users\User\AppData\Local\Temp\ipykernel_9456\2543708524.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crossfitDF2['21.3 Reps'] = crossfitDF2['21.3 Reps'].astype(int)

# %%
from pprint import pprint

# %%
crossfitDicts = crossfitDF2.to_dict('records')
crossfitDicts
# Out:
# [{'First Name': 'Tia-Clair',
#   'Last Name': 'Toomey',
#   'Placing': 1,
#   'Country': 'Australia',
#   'Continent': 'Oceania',
#   'Age': 27,
#   'Affiliate': 'CrossFit East Nashville',
#   'Height and Weight': '163 cm | 58 kg',
#   'Points': 26,
#   '21.1 Scores': '6th (11:21)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '11th (9:26)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '1st (7:37)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '8th (230 lbs)',
#   'Weight Lifted': 'Weight lifted: 230 lbs.',
#   'Height': '163 cm ',
#   'Weight': ' 58 kg'},
#  {'First Name': 'Emma',
#   'Last Name': 'Cary',
#   'Placing': 2,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 17,
#   'Affiliate': 'Perform Overcome Excel CrossFit',
#   'Height and Weight': '64 in | 140 lb',
#   'Points': 66,
#   '21.1 Scores': '14th (11:48)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '1st (8:51)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '14th (8:28)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '37th (218 lbs)',
#   'Weight Lifted': 'Weight lifted: 218 lbs.',
#   'Height': '64 in ',
#   'Weight': ' 140 lb'},
#  {'First Name': 'Kara',
#   'Last Name': 'Saunders',
#   'Placing': 3,
#   'Country': 'Australia',
#   'Continent': 'Oceania',
#   'Age': 31,
#   'Affiliate': 'CrossFit Carv',
#   'Height and Weight': '162 cm | 158 lb',
#   'Points': 111,
#   '21.1 Scores': '63rd (13:11)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '23rd (9:42)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '20th (8:41)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '5th (232 lbs)',
#   'Weight Lifted': 'Weight lifted: 232 lbs.',
#   'Height': '162 cm ',
#   'Weight': ' 158 lb'},
#  {'First Name': 'Kristi Eramo',
#   'Last Name': "O'Connell",
#   'Placing': 4,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 32,
#   'Affiliate': 'CrossFit Polaris',
#   'Height and Weight': '62 in | 132 lb',
#   'Points': 189,
#   '21.1 Scores': '121st (13:47)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '21st (9:41)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '4th (7:47)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '43rd (217 lbs)',
#   'Weight Lifted': 'Weight lifted: 217 lbs.',
#   'Height': '62 in ',
#   'Weight': ' 132 lb'},
#  {'First Name': 'Mallory',
#   'Last Name': "O'Brien",
#   'Placing': 5,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 17,
#   'Affiliate': 'Lion Brave CrossFit',
#   'Height and Weight': '63 in | 145 lb',
#   'Points': 211,
#   '21.1 Scores': '4th (11:06)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '163rd (10:38)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '2nd (7:38)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '42nd (217 lbs)',
#   'Weight Lifted': 'Weight lifted: 217 lbs.',
#   'Height': '63 in ',
#   'Weight': ' 145 lb'},
#  {'First Name': 'Emma',
#   'Last Name': 'Mcquaid',
#   'Placing': 6,
#   'Country': 'Ireland',
#   'Continent': 'Europe',
#   'Age': 31,
#   'Affiliate': 'Boundary CrossFit',
#   'Height and Weight': '165 cm | 64 kg',
#   'Points': 232,
#   '21.1 Scores': '171st (14:07)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '9th (9:24)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '27th (8:46)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '25th (224 lbs)',
#   'Weight Lifted': 'Weight lifted: 224 lbs.',
#   'Height': '165 cm ',
#   'Weight': ' 64 kg'},
#  {'First Name': 'Dani',
#   'Last Name': 'Speegle',
#   'Placing': 7,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 27,
#   'Affiliate': 'CrossFit Invictus',
#   'Height and Weight': '66 in | 168 lb',
#   'Points': 238,
#   '21.1 Scores': '114th (13:44)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '83rd (10:16)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '37th (9:00)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '4th (236 lbs)',
#   'Weight Lifted': 'Weight lifted: 236 lbs.',
#   'Height': '66 in ',
#   'Weight': ' 168 lb'},
#  {'First Name': 'Brooke',
#   'Last Name': 'Wells',
#   'Placing': 9,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 26,
#   'Affiliate': 'CrossFit Trivium',
#   'Height and Weight': '66 in | 150 lb',
#   'Points': 243,
#   '21.1 Scores': '26th (12:22)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '97th (10:21)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '18th (8:40)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '102nd (211 lbs)',
#   'Weight Lifted': 'Weight lifted: 211 lbs.',
#   'Height': '66 in ',
#   'Weight': ' 150 lb'},
#  {'First Name': 'Haley',
#   'Last Name': 'Adams',
#   'Placing': 10,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 20,
#   'Affiliate': 'CrossFit Mayhem',
#   'Height and Weight': '67 in | 140 lb',
#   'Points': 307,
#   '21.1 Scores': '8th (11:33)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '34th (9:50)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '5th (7:52)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '260th (202 lbs)',
#   'Weight Lifted': 'Weight lifted: 202 lbs.',
#   'Height': '67 in ',
#   'Weight': ' 140 lb'},
#  {'First Name': 'Matilde',
#   'Last Name': 'Garnes',
#   'Placing': 11,
#   'Country': 'Norway',
#   'Continent': 'Europe',
#   'Age': 25,
#   'Affiliate': 'CrossFit Trondheim',
#   'Height and Weight': '174 cm | 68 kg',
#   'Points': 320,
#   '21.1 Scores': '12th (11:45)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '31st (9:48)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '28th (8:48)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '249th (203 lbs)',
#   'Weight Lifted': 'Weight lifted: 203 lbs.',
#   'Height': '174 cm ',
#   'Weight': ' 68 kg'},
#  {'First Name': 'Gabriela',
#   'Last Name': 'Migała',
#   'Placing': 12,
#   'Country': 'Poland',
#   'Continent': 'Europe',
#   'Age': 22,
#   'Affiliate': 'C23 CrossFit',
#   'Height and Weight': '170 cm | 75 kg',
#   'Points': 330,
#   '21.1 Scores': '174th (14:08)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '7th (9:18)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '120th (9:41)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '29th (221 lbs)',
#   'Weight Lifted': 'Weight lifted: 221 lbs.',
#   'Height': '170 cm ',
#   'Weight': ' 75 kg'},
#  {'First Name': 'Danielle',
#   'Last Name': 'Brandon',
#   'Placing': 13,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 25,
#   'Affiliate': 'CrossFit Culmination',
#   'Height and Weight': '170 cm | 150 lb',
#   'Points': 363,
#   '21.1 Scores': '3rd (11:05)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '190th (10:43)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '64th (9:11)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '106th (210 lbs)',
#   'Weight Lifted': 'Weight lifted: 210 lbs.',
#   'Height': '170 cm ',
#   'Weight': ' 150 lb'},
#  {'First Name': 'Katrin Tanja',
#   'Last Name': 'Davidsdottir',
#   'Placing': 14,
#   'Country': 'Iceland',
#   'Continent': 'Europe',
#   'Age': 28,
#   'Affiliate': 'CrossFit New England',
#   'Height and Weight': '169 cm | 150 lb',
#   'Points': 376,
#   '21.1 Scores': '29th (12:30)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '63rd (10:08)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '109th (9:36)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '175th (206 lbs)',
#   'Weight Lifted': 'Weight lifted: 206 lbs.',
#   'Height': '169 cm ',
#   'Weight': ' 150 lb'},
#  {'First Name': 'Kari',
#   'Last Name': 'Pearce',
#   'Placing': 16,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 32,
#   'Affiliate': 'CrossFit Culmination',
#   'Height and Weight': '63 in | 139 lb',
#   'Points': 398,
#   '21.1 Scores': '52nd (13:05)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '21st (9:41)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '6th (7:56)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '319th (200 lbs)',
#   'Weight Lifted': 'Weight lifted: 200 lbs.',
#   'Height': '63 in ',
#   'Weight': ' 139 lb'},
#  {'First Name': 'Kristin',
#   'Last Name': 'Holte',
#   'Placing': 17,
#   'Country': 'Norway',
#   'Continent': 'Europe',
#   'Age': 35,
#   'Affiliate': 'CrossFit Oslo',
#   'Height and Weight': '162 cm | 59 kg',
#   'Points': 414,
#   '21.1 Scores': '19th (12:02)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '2nd (8:58)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '10th (8:10)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '383rd (198 lbs)',
#   'Weight Lifted': 'Weight lifted: 198 lbs.',
#   'Height': '162 cm ',
#   'Weight': ' 59 kg'},
#  {'First Name': 'Amanda',
#   'Last Name': 'Fusuma',
#   'Placing': 18,
#   'Country': 'Brazil',
#   'Continent': 'South America',
#   'Age': 24,
#   'Affiliate': 'CrossFit Floripa',
#   'Height and Weight': '153 cm | 56 kg',
#   'Points': 458,
#   '21.1 Scores': '296th (14:42)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '17th (9:35)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '40th (9:01)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '105th (210 lbs)',
#   'Weight Lifted': 'Weight lifted: 210 lbs.',
#   'Height': '153 cm ',
#   'Weight': ' 56 kg'},
#  {'First Name': 'Andrea',
#   'Last Name': 'Nisler',
#   'Placing': 19,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 32,
#   'Affiliate': 'CrossFit Mayhem',
#   'Height and Weight': '66 in | 154 lb',
#   'Points': 460,
#   '21.1 Scores': '325th (14:48)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '61st (10:06)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '46th (9:04)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '28th (221 lbs)',
#   'Weight Lifted': 'Weight lifted: 221 lbs.',
#   'Height': '66 in ',
#   'Weight': ' 154 lb'},
#  {'First Name': 'Amanda',
#   'Last Name': 'Barnhart',
#   'Placing': 20,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 29,
#   'Affiliate': 'CrossFit New England',
#   'Height and Weight': '67 in | 160 lb',
#   'Points': 463,
#   '21.1 Scores': '196th (14:18)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '99th (10:23)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '152nd (9:54)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '16th (225 lbs)',
#   'Weight Lifted': 'Weight lifted: 225 lbs.',
#   'Height': '67 in ',
#   'Weight': ' 160 lb'},
#  {'First Name': 'Bethany',
#   'Last Name': 'Shadburne',
#   'Placing': 21,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 27,
#   'Affiliate': 'CrossFit Culmination',
#   'Height and Weight': '64 in | 144 lb',
#   'Points': 464,
#   '21.1 Scores': '121st (13:47)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '46th (10:00)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '3rd (7:40)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '294th (201 lbs)',
#   'Weight Lifted': 'Weight lifted: 201 lbs.',
#   'Height': '64 in ',
#   'Weight': ' 144 lb'},
#  {'First Name': 'Chloe',
#   'Last Name': 'Gauvin-David',
#   'Placing': 22,
#   'Country': 'Canada',
#   'Continent': 'North America',
#   'Age': 29,
#   'Affiliate': 'CrossFit Pro1',
#   'Height and Weight': '67 in | 146 lb',
#   'Points': 479,
#   '21.1 Scores': '28th (12:25)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '171st (10:40)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '18th (8:40)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '262nd (202 lbs)',
#   'Weight Lifted': 'Weight lifted: 202 lbs.',
#   'Height': '67 in ',
#   'Weight': ' 146 lb'},
#  {'First Name': 'Larissa',
#   'Last Name': 'Cunha',
#   'Placing': 23,
#   'Country': 'Brazil',
#   'Continent': 'South America',
#   'Age': 30,
#   'Affiliate': 'Cavaleiros CrossFit',
#   'Height and Weight': '153 cm | 62 kg',
#   'Points': 498,
#   '21.1 Scores': '260th (14:34)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '91st (10:19)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '16th (8:34)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '131st (208 lbs)',
#   'Weight Lifted': 'Weight lifted: 208 lbs.',
#   'Height': '153 cm ',
#   'Weight': ' 62 kg'},
#  {'First Name': 'Amy',
#   'Last Name': 'Morton',
#   'Placing': 24,
#   'Country': 'Canada',
#   'Continent': 'North America',
#   'Age': 33,
#   'Affiliate': 'Ocean State CrossFit',
#   'Height and Weight': '163 cm | 154 lb',
#   'Points': 522,
#   '21.1 Scores': '284th (14:39)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '99th (10:23)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '50th (9:06)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '89th (212 lbs)',
#   'Weight Lifted': 'Weight lifted: 212 lbs.',
#   'Height': '163 cm ',
#   'Weight': ' 154 lb'},
#  {'First Name': 'Carol-Ann',
#   'Last Name': 'Reason-Thibault',
#   'Placing': 28,
#   'Country': 'Canada',
#   'Continent': 'North America',
#   'Age': 33,
#   'Affiliate': 'CrossFit 514',
#   'Height and Weight': '164 cm | 142 lb',
#   'Points': 567,
#   '21.1 Scores': '89th (13:29)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '119th (10:29)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '37th (9:00)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '322nd (200 lbs)',
#   'Weight Lifted': 'Weight lifted: 200 lbs.',
#   'Height': '164 cm ',
#   'Weight': ' 142 lb'},
#  {'First Name': 'Thuridur Erla',
#   'Last Name': 'Helgadottir',
#   'Placing': 29,
#   'Country': 'Iceland',
#   'Continent': 'Europe',
#   'Age': 29,
#   'Affiliate': 'CrossFit Zug',
#   'Height and Weight': '164 cm | 59 kg',
#   'Points': 573,
#   '21.1 Scores': '31st (12:39)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '59th (10:05)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '98th (9:32)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '385th (198 lbs)',
#   'Weight Lifted': 'Weight lifted: 198 lbs.',
#   'Height': '164 cm ',
#   'Weight': ' 59 kg'},
#  {'First Name': 'Kristine',
#   'Last Name': 'Best',
#   'Placing': 30,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 31,
#   'Affiliate': 'CrossFit Undivided',
#   'Height and Weight': '63 in | 138 lb',
#   'Points': 588,
#   '21.1 Scores': '269th (14:36)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '20th (9:38)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '36th (8:56)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '263rd (202 lbs)',
#   'Weight Lifted': 'Weight lifted: 202 lbs.',
#   'Height': '63 in ',
#   'Weight': ' 138 lb'},
#  {'First Name': 'Madeline',
#   'Last Name': 'Shelling',
#   'Placing': 31,
#   'Country': 'New Zealand',
#   'Continent': 'Oceania',
#   'Age': 27,
#   'Affiliate': 'Plus64 CrossFit',
#   'Height and Weight': '165 cm | 69 kg',
#   'Points': 638,
#   '21.1 Scores': '126th (13:48)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '42nd (9:57)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '220th (10:15)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '250th (203 lbs)',
#   'Weight Lifted': 'Weight lifted: 203 lbs.',
#   'Height': '165 cm ',
#   'Weight': ' 69 kg'},
#  {'First Name': 'Karin',
#   'Last Name': 'Freyová',
#   'Placing': 32,
#   'Country': 'Slovakia',
#   'Continent': 'Europe',
#   'Age': 26,
#   'Affiliate': 'CrossFit Alpha Prime',
#   'Height and Weight': '170 cm | 72 kg',
#   'Points': 640,
#   '21.1 Scores': '77th (13:23)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '221st (10:49)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '327th (10:42)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '15th (226 lbs)',
#   'Weight Lifted': 'Weight lifted: 226 lbs.',
#   'Height': '170 cm ',
#   'Weight': ' 72 kg'},
#  {'First Name': 'Mekenzie',
#   'Last Name': 'Riley',
#   'Placing': 33,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 33,
#   'Affiliate': 'CrossFit Northlake',
#   'Height and Weight': '64 in | 155 lb',
#   'Points': 652,
#   '21.1 Scores': '128th (13:49)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '171st (10:40)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '161st (9:57)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '192nd (205 lbs)',
#   'Weight Lifted': 'Weight lifted: 205 lbs.',
#   'Height': '64 in ',
#   'Weight': ' 155 lb'},
#  {'First Name': 'Shelby',
#   'Last Name': 'Neal',
#   'Placing': 34,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 21,
#   'Affiliate': '12th State CrossFit',
#   'Height and Weight': '62 in | 135 lb',
#   'Points': 655,
#   '21.1 Scores': '102nd (13:36)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '81st (10:15)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '50th (9:06)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '422nd (197 lbs)',
#   'Weight Lifted': 'Weight lifted: 197 lbs.',
#   'Height': '62 in ',
#   'Weight': ' 135 lb'},
#  {'First Name': 'Jacqueline',
#   'Last Name': 'Dahlstrøm',
#   'Placing': 35,
#   'Country': 'Norway',
#   'Continent': 'Europe',
#   'Age': 29,
#   'Affiliate': 'C23 CrossFit',
#   'Height and Weight': '167 cm | 67 kg',
#   'Points': 658,
#   '21.1 Scores': '360th (14:54)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '24th (9:43)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '13th (8:21)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '261st (202 lbs)',
#   'Weight Lifted': 'Weight lifted: 202 lbs.',
#   'Height': '167 cm ',
#   'Weight': ' 67 kg'},
#  {'First Name': 'Mandi',
#   'Last Name': 'Janowitz',
#   'Placing': 37,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 35,
#   'Affiliate': 'Rockwell CrossFit',
#   'Height and Weight': '65 in | 150 lb',
#   'Points': 666,
#   '21.1 Scores': '181st (14:11)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '382nd (11:08)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '44th (9:03)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '59th (215 lbs)',
#   'Weight Lifted': 'Weight lifted: 215 lbs.',
#   'Height': '65 in ',
#   'Weight': ' 150 lb'},
#  {'First Name': 'Paige',
#   'Last Name': 'Semenza',
#   'Placing': 39,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 29,
#   'Affiliate': 'CrossFit Vertex',
#   'Height and Weight': '63 in | 143 lb',
#   'Points': 685,
#   '21.1 Scores': '148th (13:57)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '43rd (9:58)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '71st (9:13)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '423rd (197 lbs)',
#   'Weight Lifted': 'Weight lifted: 197 lbs.',
#   'Height': '63 in ',
#   'Weight': ' 143 lb'},
#  {'First Name': 'Emma',
#   'Last Name': 'Tall',
#   'Placing': 42,
#   'Country': 'Sweden',
#   'Continent': 'Europe',
#   'Age': 29,
#   'Affiliate': 'CrossFit Karlstad',
#   'Height and Weight': '168 cm | 68 kg',
#   'Points': 716,
#   '21.1 Scores': '235th (14:28)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '125th (10:30)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '114th (9:39)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '242nd (204 lbs)',
#   'Weight Lifted': 'Weight lifted: 204 lbs.',
#   'Height': '168 cm ',
#   'Weight': ' 68 kg'},
#  {'First Name': 'Kloie',
#   'Last Name': 'Wilson',
#   'Placing': 44,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 23,
#   'Affiliate': 'CrossFit Dixie',
#   'Height and Weight': '67 in | 155 lb',
#   'Points': 736,
#   '21.1 Scores': '208th (14:21)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '420th (11:13)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '98th (9:32)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '10th (228 lbs)',
#   'Weight Lifted': 'Weight lifted: 228 lbs.',
#   'Height': '67 in ',
#   'Weight': ' 155 lb'},
#  {'First Name': 'Antea',
#   'Last Name': 'Longo',
#   'Placing': 46,
#   'Country': 'Italy',
#   'Continent': 'Europe',
#   'Age': 33,
#   'Affiliate': 'CrossFit FFA',
#   'Height and Weight': '160 cm | 60 kg',
#   'Points': 743,
#   '21.1 Scores': '57th (13:09)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '312th (11:00)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '50th (9:06)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '324th (200 lbs)',
#   'Weight Lifted': 'Weight lifted: 200 lbs.',
#   'Height': '160 cm ',
#   'Weight': ' 60 kg'},
#  {'First Name': 'Gabriella',
#   'Last Name': 'Moratti',
#   'Placing': 47,
#   'Country': 'Brazil',
#   'Continent': 'South America',
#   'Age': 21,
#   'Affiliate': 'CrossFit Berrini',
#   'Height and Weight': '163 cm | 62 kg',
#   'Points': 770,
#   '21.1 Scores': '110th (13:43)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '496th (11:21)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '126th (9:43)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '38th (218 lbs)',
#   'Weight Lifted': 'Weight lifted: 218 lbs.',
#   'Height': '163 cm ',
#   'Weight': ' 62 kg'},
#  {'First Name': 'Madeline',
#   'Last Name': 'Sturt',
#   'Placing': 48,
#   'Country': 'Australia',
#   'Continent': 'Oceania',
#   'Age': 24,
#   'Affiliate': 'Reebok CrossFit Frankston',
#   'Height and Weight': '158 cm | 62 kg',
#   'Points': 785,
#   '21.1 Scores': '96th (13:32)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '370th (11:07)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '23rd (8:45)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '296th (201 lbs)',
#   'Weight Lifted': 'Weight lifted: 201 lbs.',
#   'Height': '158 cm ',
#   'Weight': ' 62 kg'},
#  {'First Name': 'Hanna',
#   'Last Name': 'Karlsson',
#   'Placing': 49,
#   'Country': 'Sweden',
#   'Continent': 'Europe',
#   'Age': 28,
#   'Affiliate': 'CrossFit Mejeriet',
#   'Height and Weight': '177 cm | 81 kg',
#   'Points': 786,
#   '21.1 Scores': '225th (14:26)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '99th (10:23)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '354th (10:47)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '108th (210 lbs)',
#   'Weight Lifted': 'Weight lifted: 210 lbs.',
#   'Height': '177 cm ',
#   'Weight': ' 81 kg'},
#  {'First Name': 'Emily',
#   'Last Name': 'Rolfe',
#   'Placing': 50,
#   'Country': 'Canada',
#   'Continent': 'North America',
#   'Age': 32,
#   'Affiliate': 'CrossFit Sea Level',
#   'Height and Weight': '170 cm | 152 lb',
#   'Points': 791,
#   '21.1 Scores': '39th (12:56)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '209th (10:47)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '46th (9:04)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '497th (195 lbs)',
#   'Weight Lifted': 'Weight lifted: 195 lbs.',
#   'Height': '170 cm ',
#   'Weight': ' 152 lb'},
#  {'First Name': 'Christee',
#   'Last Name': 'Bishop',
#   'Placing': 51,
#   'Country': 'Australia',
#   'Continent': 'Oceania',
#   'Age': 30,
#   'Affiliate': 'CrossFit 4740',
#   'Height and Weight': '158 cm | 60 kg',
#   'Points': 819,
#   '21.1 Scores': '23rd (12:12)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '68th (10:10)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '248th (10:24)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '480th (196 lbs)',
#   'Weight Lifted': 'Weight lifted: 196 lbs.',
#   'Height': '158 cm ',
#   'Weight': ' 60 kg'},
#  {'First Name': 'Laura',
#   'Last Name': 'Horváth',
#   'Placing': 52,
#   'Country': 'Hungary',
#   'Continent': 'Europe',
#   'Age': 24,
#   'Affiliate': 'CrossFit Glasshouse',
#   'Height and Weight': '170 cm | 70 kg',
#   'Points': 845,
#   '21.1 Scores': '181st (14:11)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '602nd (11:30)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '31st (8:54)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '31st (220 lbs)',
#   'Weight Lifted': 'Weight lifted: 220 lbs.',
#   'Height': '170 cm ',
#   'Weight': ' 70 kg'},
#  {'First Name': 'Olivia',
#   'Last Name': 'Sulek',
#   'Placing': 52,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 17,
#   'Affiliate': 'ESF CrossFit',
#   'Height and Weight': '65 in | 145 lb',
#   'Points': 845,
#   '21.1 Scores': '198th (14:19)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88th (10:18)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '256th (10:25)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '303rd (201 lbs)',
#   'Weight Lifted': 'Weight lifted: 201 lbs.',
#   'Height': '65 in ',
#   'Weight': ' 145 lb'},
#  {'First Name': 'Freya',
#   'Last Name': 'Moosbrugger',
#   'Placing': 54,
#   'Country': 'Canada',
#   'Continent': 'North America',
#   'Age': 19,
#   'Affiliate': 'CrossFit Fraser Valley',
#   'Height and Weight': '165 cm | 67 kg',
#   'Points': 872,
#   '21.1 Scores': '325th (14:48)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '239th (10:51)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '176th (10:00)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '132nd (208 lbs)',
#   'Weight Lifted': 'Weight lifted: 208 lbs.',
#   'Height': '165 cm ',
#   'Weight': ' 67 kg'},
#  {'First Name': 'Marykay',
#   'Last Name': 'Dreisilker',
#   'Placing': 56,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 31,
#   'Affiliate': 'CrossFit Omnia',
#   'Height and Weight': '63 in | 150 lb',
#   'Points': 889,
#   '21.1 Scores': '216th (14:24)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '346th (11:04)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '137th (9:47)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '190th (205 lbs)',
#   'Weight Lifted': 'Weight lifted: 205 lbs.',
#   'Height': '63 in ',
#   'Weight': ' 150 lb'},
#  {'First Name': 'Manon',
#   'Last Name': 'Lesur',
#   'Placing': 59,
#   'Country': 'France',
#   'Continent': 'Europe',
#   'Age': 30,
#   'Affiliate': 'CrossFit Pro1',
#   'Height and Weight': '163 cm | 145 lb',
#   'Points': 898,
#   '21.1 Scores': '284th (14:39)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '245th (10:52)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '219th (10:14)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '150th (207 lbs)',
#   'Weight Lifted': 'Weight lifted: 207 lbs.',
#   'Height': '163 cm ',
#   'Weight': ' 145 lb'},
#  {'First Name': 'Justine',
#   'Last Name': 'Beath',
#   'Placing': 60,
#   'Country': 'Australia',
#   'Continent': 'Oceania',
#   'Age': 31,
#   'Affiliate': 'CrossFit Lower Mountains',
#   'Height and Weight': '163 cm | 140 lb',
#   'Points': 920,
#   '21.1 Scores': '163rd (14:02)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '71st (10:11)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '298th (10:34)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '388th (198 lbs)',
#   'Weight Lifted': 'Weight lifted: 198 lbs.',
#   'Height': '163 cm ',
#   'Weight': ' 140 lb'},
#  {'First Name': 'Feeroozeh',
#   'Last Name': 'Saghafi',
#   'Placing': 62,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 26,
#   'Affiliate': 'CrossFit Mentality',
#   'Height and Weight': '62 in | 130 lb',
#   'Points': 949,
#   '21.1 Scores': '198th (14:19)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '35th (9:53)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '33rd (8:55)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '683rd (191 lbs)',
#   'Weight Lifted': 'Weight lifted: 191 lbs.',
#   'Height': '62 in ',
#   'Weight': ' 130 lb'},
#  {'First Name': 'Kelly',
#   'Last Name': 'Clark',
#   'Placing': 63,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 34,
#   'Affiliate': 'CrossFit Up',
#   'Height and Weight': '64 in | 145 lb',
#   'Points': 960,
#   '21.1 Scores': '397th (14:59)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '363rd (11:06)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '161st (9:57)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '39th (218 lbs)',
#   'Weight Lifted': 'Weight lifted: 218 lbs.',
#   'Height': '64 in ',
#   'Weight': ' 145 lb'},
#  {'First Name': 'Mikaela',
#   'Last Name': 'Norman',
#   'Placing': 64,
#   'Country': 'Sweden',
#   'Continent': 'Europe',
#   'Age': 28,
#   'Affiliate': 'CrossFit Nordic',
#   'Height and Weight': '179 cm | 68 kg',
#   'Points': 984,
#   '21.1 Scores': '32nd (12:43)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '141st (10:34)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '102nd (9:33)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '709th (190 lbs)',
#   'Weight Lifted': 'Weight lifted: 190 lbs.',
#   'Height': '179 cm ',
#   'Weight': ' 68 kg'},
#  {'First Name': 'Taylor',
#   'Last Name': 'Rector',
#   'Placing': 65,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 28,
#   'Affiliate': 'CrossFit Nixa',
#   'Height and Weight': '64 in | 154 lb',
#   'Points': 1008,
#   '21.1 Scores': '273rd (14:37)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '273rd (10:56)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '309th (10:37)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '153rd (207 lbs)',
#   'Weight Lifted': 'Weight lifted: 207 lbs.',
#   'Height': '64 in ',
#   'Weight': ' 154 lb'},
#  {'First Name': 'Camilla',
#   'Last Name': 'Salomonsson Hellman',
#   'Placing': 66,
#   'Country': 'Sweden',
#   'Continent': 'Europe',
#   'Age': 30,
#   'Affiliate': 'Styrka CrossFit',
#   'Height and Weight': '165 cm | 69 kg',
#   'Points': 1015,
#   '21.1 Scores': '85th (13:27)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '190th (10:43)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '365th (10:49)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '375th (199 lbs)',
#   'Weight Lifted': 'Weight lifted: 199 lbs.',
#   'Height': '165 cm ',
#   'Weight': ' 69 kg'},
#  {'First Name': 'Mary Helen',
#   'Last Name': 'Saunders',
#   'Placing': 67,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 29,
#   'Affiliate': 'CrossFit Invigorate',
#   'Height and Weight': '64 in | 142 lb',
#   'Points': 1023,
#   '21.1 Scores': '224th (14:25)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '264th (10:55)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '234th (10:20)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '301st (201 lbs)',
#   'Weight Lifted': 'Weight lifted: 201 lbs.',
#   'Height': '64 in ',
#   'Weight': ' 142 lb'},
#  {'First Name': 'Yuko',
#   'Last Name': 'Sakuyama',
#   'Placing': 69,
#   'Country': 'Japan',
#   'Continent': 'Asia',
#   'Age': 34,
#   'Affiliate': 'CrossFit Roppongi',
#   'Height and Weight': '152 cm | 125 lb',
#   'Points': 1062,
#   '21.1 Scores': '42nd (12:58)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '256th (10:54)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '80th (9:19)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '684th (191 lbs)',
#   'Weight Lifted': 'Weight lifted: 191 lbs.',
#   'Height': '152 cm ',
#   'Weight': ' 125 lb'},
#  {'First Name': 'Kaela',
#   'Last Name': 'Stephano',
#   'Placing': 70,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 20,
#   'Affiliate': 'CrossFit Hype',
#   'Height and Weight': '61 in | 116 lb',
#   'Points': 1064,
#   '21.1 Scores': '74th (13:19)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '733rd (11:41)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '69th (9:12)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '188th (205 lbs)',
#   'Weight Lifted': 'Weight lifted: 205 lbs.',
#   'Height': '61 in ',
#   'Weight': ' 116 lb'},
#  {'First Name': 'Emelie',
#   'Last Name': 'Lundberg',
#   'Placing': 71,
#   'Country': 'Sweden',
#   'Continent': 'Europe',
#   'Age': 31,
#   'Affiliate': 'CrossFit Borgen',
#   'Height and Weight': '162 cm | 68 kg',
#   'Points': 1066,
#   '21.1 Scores': '253rd (14:32)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '141st (10:34)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '298th (10:34)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '374th (199 lbs)',
#   'Weight Lifted': 'Weight lifted: 199 lbs.',
#   'Height': '162 cm ',
#   'Weight': ' 68 kg'},
#  {'First Name': 'Leigha',
#   'Last Name': 'Dean',
#   'Placing': 73,
#   'Country': 'Canada',
#   'Continent': 'North America',
#   'Age': 29,
#   'Affiliate': 'CrossFit 1855',
#   'Height and Weight': '161 cm | 137 lb',
#   'Points': 1075,
#   '21.1 Scores': '360th (14:54)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '180th (10:41)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '111th (9:37)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '424th (197 lbs)',
#   'Weight Lifted': 'Weight lifted: 197 lbs.',
#   'Height': '161 cm ',
#   'Weight': ' 137 lb'},
#  {'First Name': 'Emma',
#   'Last Name': 'Chapman',
#   'Placing': 75,
#   'Country': 'New Zealand',
#   'Continent': 'Oceania',
#   'Age': 33,
#   'Affiliate': 'CrossFit Berea',
#   'Height and Weight': '62 in | 130 lb',
#   'Points': 1084,
#   '21.1 Scores': '151st (13:59)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '12th (9:27)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '15th (8:33)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '906th (187 lbs)',
#   'Weight Lifted': 'Weight lifted: 187 lbs.',
#   'Height': '62 in ',
#   'Weight': ' 130 lb'},
#  {'First Name': 'Taylor',
#   'Last Name': 'Streid',
#   'Placing': 76,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 30,
#   'Affiliate': 'Blues City CrossFit',
#   'Height and Weight': '66 in | 140 lb',
#   'Points': 1087,
#   '21.1 Scores': '149th (13:58)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '190th (10:43)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '132nd (9:46)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '616th (192 lbs)',
#   'Weight Lifted': 'Weight lifted: 192 lbs.',
#   'Height': '66 in ',
#   'Weight': ' 140 lb'},
#  {'First Name': 'Brenda',
#   'Last Name': 'Castro',
#   'Placing': 77,
#   'Country': 'Mexico',
#   'Continent': 'North America',
#   'Age': 32,
#   'Affiliate': 'CrossFit Tigran',
#   'Height and Weight': '2 cm | 139 lb',
#   'Points': 1100,
#   '21.1 Scores': '158th (14:01)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '590th (11:29)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '176th (10:00)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '176th (206 lbs)',
#   'Weight Lifted': 'Weight lifted: 206 lbs.',
#   'Height': '2 cm ',
#   'Weight': ' 139 lb'},
#  {'First Name': 'Svetlana',
#   'Last Name': 'Kubyshkina',
#   'Placing': 79,
#   'Country': 'Russian Federation',
#   'Continent': 'Asia',
#   'Age': 30,
#   'Affiliate': 'Backstage CrossFit',
#   'Height and Weight': '155 cm | 60 kg',
#   'Points': 1134,
#   '21.1 Scores': '59th (13:10)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88th (10:18)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '77th (9:17)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '910th (187 lbs)',
#   'Weight Lifted': 'Weight lifted: 187 lbs.',
#   'Height': '155 cm ',
#   'Weight': ' 60 kg'},
#  {'First Name': 'Samantha',
#   'Last Name': 'Briggs',
#   'Placing': 80,
#   'Country': 'United Kingdom',
#   'Continent': 'Europe',
#   'Age': 39,
#   'Affiliate': 'CrossFit Black Five',
#   'Height and Weight': '170 cm | 135 lb',
#   'Points': 1136,
#   '21.1 Scores': '188th (14:14)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '32nd (9:49)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '11th (8:19)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '905th (187 lbs)',
#   'Weight Lifted': 'Weight lifted: 187 lbs.',
#   'Height': '170 cm ',
#   'Weight': ' 135 lb'},
#  {'First Name': 'Kelly',
#   'Last Name': 'Stone',
#   'Placing': 81,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 30,
#   'Affiliate': 'CrossFit Omnia',
#   'Height and Weight': '65 in | 150 lb',
#   'Points': 1155,
#   '21.1 Scores': '66th (13:13)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '835th (11:48)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '109th (9:36)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '145th (207 lbs)',
#   'Weight Lifted': 'Weight lifted: 207 lbs.',
#   'Height': '65 in ',
#   'Weight': ' 150 lb'},
#  {'First Name': 'Cassidy',
#   'Last Name': 'Lance-Mcwherter',
#   'Placing': 82,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 33,
#   'Affiliate': 'CrossFit WaterSide',
#   'Height and Weight': '63 in | 140 lb',
#   'Points': 1167,
#   '21.1 Scores': '80th (13:25)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '490th (11:20)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '330th (10:43)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '267th (202 lbs)',
#   'Weight Lifted': 'Weight lifted: 202 lbs.',
#   'Height': '63 in ',
#   'Weight': ' 140 lb'},
#  {'First Name': 'Laura',
#   'Last Name': 'Gonzalez-Marin',
#   'Placing': 84,
#   'Country': 'Venezuela',
#   'Continent': 'South America',
#   'Age': 27,
#   'Affiliate': 'Caution CrossFit Miami Lakes',
#   'Height and Weight': '67 in | 148 lb',
#   'Points': 1172,
#   '21.1 Scores': '92nd (13:31)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '155th (10:36)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '340th (10:44)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '585th (193 lbs)',
#   'Weight Lifted': 'Weight lifted: 193 lbs.',
#   'Height': '67 in ',
#   'Weight': ' 148 lb'},
#  {'First Name': 'Bailey',
#   'Last Name': 'Meraviglia',
#   'Placing': 87,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 30,
#   'Affiliate': 'Stroud CrossFit',
#   'Height and Weight': '62 in | 138 lb',
#   'Points': 1179,
#   '21.1 Scores': '319th (14:47)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '187th (10:42)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '172nd (9:59)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '501st (195 lbs)',
#   'Weight Lifted': 'Weight lifted: 195 lbs.',
#   'Height': '62 in ',
#   'Weight': ' 138 lb'},
#  {'First Name': 'Ella',
#   'Last Name': 'Wunger',
#   'Placing': 93,
#   'Country': 'Sweden',
#   'Continent': 'Europe',
#   'Age': 23,
#   'Affiliate': 'C23 CrossFit',
#   'Height and Weight': '170 cm | 65 kg',
#   'Points': 1248,
#   '21.1 Scores': '154th (14:00)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '38th (9:55)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '189th (10:03)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '867th (188 lbs)',
#   'Weight Lifted': 'Weight lifted: 188 lbs.',
#   'Height': '170 cm ',
#   'Weight': ' 65 kg'},
#  {'First Name': 'Emilia',
#   'Last Name': 'Leppänen',
#   'Placing': 94,
#   'Country': 'Finland',
#   'Continent': 'Europe',
#   'Age': 34,
#   'Affiliate': 'CrossFit 10K',
#   'Height and Weight': '165 cm | 150 lb',
#   'Points': 1256,
#   '21.1 Scores': '107th (13:41)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '141st (10:34)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '96th (9:30)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '912th (187 lbs)',
#   'Weight Lifted': 'Weight lifted: 187 lbs.',
#   'Height': '165 cm ',
#   'Weight': ' 150 lb'},
#  {'First Name': 'Alexis',
#   'Last Name': 'Raptis',
#   'Placing': 95,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 22,
#   'Affiliate': 'C2X CrossFit',
#   'Height and Weight': '65 in | 138 lb',
#   'Points': 1270,
#   '21.1 Scores': '5th (11:14)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '250th (10:53)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '102nd (9:33)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '913th (187 lbs)',
#   'Weight Lifted': 'Weight lifted: 187 lbs.',
#   'Height': '65 in ',
#   'Weight': ' 138 lb'},
#  {'First Name': 'Rachel',
#   'Last Name': 'Thibodeaux',
#   'Placing': 97,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 28,
#   'Affiliate': 'JH CrossFit',
#   'Height and Weight': '63 in | 130 lb',
#   'Points': 1298,
#   '21.1 Scores': '278th (14:38)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '283rd (10:57)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '256th (10:25)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '481st (196 lbs)',
#   'Weight Lifted': 'Weight lifted: 196 lbs.',
#   'Height': '63 in ',
#   'Weight': ' 130 lb'},
#  {'First Name': 'Kaitlyn',
#   'Last Name': 'Anapolsky',
#   'Placing': 98,
#   'Country': 'Canada',
#   'Continent': 'North America',
#   'Age': 30,
#   'Affiliate': 'CrossFit PSC',
#   'Height and Weight': '63 in | 150 lb',
#   'Points': 1304,
#   '21.1 Scores': '253rd (14:32)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '510th (11:23)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '239th (10:21)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '302nd (201 lbs)',
#   'Weight Lifted': 'Weight lifted: 201 lbs.',
#   'Height': '63 in ',
#   'Weight': ' 150 lb'},
#  {'First Name': 'Lucy',
#   'Last Name': 'Campbell',
#   'Placing': 99,
#   'Country': 'United Kingdom',
#   'Continent': 'Europe',
#   'Age': 25,
#   'Affiliate': 'CrossFit Nottingham',
#   'Height and Weight': '168 cm | 74 kg',
#   'Points': 1324,
#   '21.1 Scores': '80th (13:25)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '27th (9:45)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '142nd (9:49)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '1075th (186 lbs)',
#   'Weight Lifted': 'Weight lifted: 186 lbs.',
#   'Height': '168 cm ',
#   'Weight': ' 74 kg'},
#  {'First Name': 'Tatiana',
#   'Last Name': 'Membré',
#   'Placing': 100,
#   'Country': 'France',
#   'Continent': 'Europe',
#   'Age': 31,
#   'Affiliate': 'CrossFit Avignon',
#   'Height and Weight': '157 cm | 63 kg',
#   'Points': 1325,
#   '21.1 Scores': '389th (14:58)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '432nd (11:14)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '309th (10:37)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '195th (205 lbs)',
#   'Weight Lifted': 'Weight lifted: 205 lbs.',
#   'Height': '157 cm ',
#   'Weight': ' 63 kg'},
#  {'First Name': 'Taylor',
#   'Last Name': 'Ballek',
#   'Placing': 102,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 24,
#   'Affiliate': 'CrossFit Invictus',
#   'Height and Weight': '65 in | 140 lb',
#   'Points': 1329,
#   '21.1 Scores': '244th (14:30)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '119th (10:29)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '58th (9:09)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '908th (187 lbs)',
#   'Weight Lifted': 'Weight lifted: 187 lbs.',
#   'Height': '65 in ',
#   'Weight': ' 140 lb'},
#  {'First Name': 'Faith',
#   'Last Name': 'Ferguson',
#   'Placing': 104,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 20,
#   'Affiliate': 'CrossFit Maven',
#   'Height and Weight': '63 in | 150 lb',
#   'Points': 1367,
#   '21.1 Scores': '55th (13:08)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '556th (11:27)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '172nd (9:59)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '584th (193 lbs)',
#   'Weight Lifted': 'Weight lifted: 193 lbs.',
#   'Height': '63 in ',
#   'Weight': ' 150 lb'},
#  {'First Name': 'Stephanie',
#   'Last Name': 'Chung',
#   'Placing': 106,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 29,
#   'Affiliate': 'CrossFit Invictus Back Bay',
#   'Height and Weight': '65 in | 150 lb',
#   'Points': 1373,
#   '21.1 Scores': '107th (13:41)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '228th (10:50)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '172nd (9:59)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '866th (188 lbs)',
#   'Weight Lifted': 'Weight lifted: 188 lbs.',
#   'Height': '65 in ',
#   'Weight': ' 150 lb'},
#  {'First Name': 'Lexi',
#   'Last Name': 'Colabianchi',
#   'Placing': 109,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 27,
#   'Affiliate': 'Derby City CrossFit',
#   'Height and Weight': '62 in | 130 lb',
#   'Points': 1430,
#   '21.1 Scores': '134th (13:51)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '523rd (11:24)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '502nd (11:20)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '271st (202 lbs)',
#   'Weight Lifted': 'Weight lifted: 202 lbs.',
#   'Height': '62 in ',
#   'Weight': ' 130 lb'},
#  {'First Name': 'Mariska',
#   'Last Name': 'Smit',
#   'Placing': 110,
#   'Country': 'South Africa',
#   'Continent': 'Africa',
#   'Age': 28,
#   'Affiliate': 'CrossFit Eikestad',
#   'Height and Weight': '168 cm | 64 kg',
#   'Points': 1432,
#   '21.1 Scores': '211th (14:22)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '199th (10:44)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '309th (10:37)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '713th (190 lbs)',
#   'Weight Lifted': 'Weight lifted: 190 lbs.',
#   'Height': '168 cm ',
#   'Weight': ' 64 kg'},
#  {'First Name': 'Claudia',
#   'Last Name': 'Gluck',
#   'Placing': 111,
#   'Country': 'France',
#   'Continent': 'Europe',
#   'Age': 22,
#   'Affiliate': 'CrossFit Grillen',
#   'Height and Weight': '160 cm | 60 kg',
#   'Points': 1434,
#   '21.1 Scores': '171st (14:07)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '228th (10:50)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '120th (9:41)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '915th (187 lbs)',
#   'Weight Lifted': 'Weight lifted: 187 lbs.',
#   'Height': '160 cm ',
#   'Weight': ' 60 kg'},
#  {'First Name': 'Jordan',
#   'Last Name': 'Adcock',
#   'Placing': 112,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 29,
#   'Affiliate': 'Kawi CrossFit',
#   'Height and Weight': '66 in | 140 lb',
#   'Points': 1444,
#   '21.1 Scores': '186th (14:13)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '228th (10:50)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '440th (11:09)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '590th (193 lbs)',
#   'Weight Lifted': 'Weight lifted: 193 lbs.',
#   'Height': '66 in ',
#   'Weight': ' 140 lb'},
#  {'First Name': 'Aimee',
#   'Last Name': 'Tawhai',
#   'Placing': 115,
#   'Country': 'New Zealand',
#   'Continent': 'Oceania',
#   'Age': 29,
#   'Affiliate': 'CrossFit Project Bayside',
#   'Height and Weight': '163 cm | 66 kg',
#   'Points': 1475,
#   '21.1 Scores': '225th (14:26)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '115th (10:28)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '286th (10:31)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '849th (189 lbs)',
#   'Weight Lifted': 'Weight lifted: 189 lbs.',
#   'Height': '163 cm ',
#   'Weight': ' 66 kg'},
#  {'First Name': 'Brittany',
#   'Last Name': 'Marella',
#   'Placing': 116,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 29,
#   'Affiliate': 'CrossFit Athletic Academy',
#   'Height and Weight': '63 in | 150 lb',
#   'Points': 1486,
#   '21.1 Scores': '191st (14:17)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '370th (11:07)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '340th (10:44)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '585th (193 lbs)',
#   'Weight Lifted': 'Weight lifted: 193 lbs.',
#   'Height': '63 in ',
#   'Weight': ' 150 lb'},
#  {'First Name': 'Rebecca',
#   'Last Name': 'Voigt Miller',
#   'Placing': 120,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 40,
#   'Affiliate': 'CrossFit Training Yard',
#   'Height and Weight': '69 in | 152 lb',
#   'Points': 1542,
#   '21.1 Scores': '225th (14:26)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '395th (11:10)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '345th (10:45)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '577th (194 lbs)',
#   'Weight Lifted': 'Weight lifted: 194 lbs.',
#   'Height': '69 in ',
#   'Weight': ' 152 lb'},
#  {'First Name': 'Janie',
#   'Last Name': 'Garratt',
#   'Placing': 122,
#   'Country': 'United Kingdom',
#   'Continent': 'Europe',
#   'Age': 28,
#   'Affiliate': 'CrossFit Mayflower',
#   'Height and Weight': '158 cm | 63 kg',
#   'Points': 1558,
#   '21.1 Scores': '75th (13:21)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '483rd (11:19)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '411th (11:01)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '589th (193 lbs)',
#   'Weight Lifted': 'Weight lifted: 193 lbs.',
#   'Height': '158 cm ',
#   'Weight': ' 63 kg'},
#  {'First Name': 'Joey',
#   'Last Name': 'Kimdon',
#   'Placing': 126,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 43,
#   'Affiliate': 'CrossFit Train 97333',
#   'Height and Weight': '61 in | 125 lb',
#   'Points': 1628,
#   '21.1 Scores': '98th (13:34)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '456th (11:17)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '155th (9:55)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '919th (187 lbs)',
#   'Weight Lifted': 'Weight lifted: 187 lbs.',
#   'Height': '61 in ',
#   'Weight': ' 125 lb'},
#  {'First Name': 'Carol',
#   'Last Name': 'Colling',
#   'Placing': 127,
#   'Country': 'Paraguay',
#   'Continent': 'South America',
#   'Age': 28,
#   'Affiliate': 'Kingbull CrossFit',
#   'Height and Weight': '157 cm | 57 kg',
#   'Points': 1633,
#   '21.1 Scores': '191st (14:17)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '646th (11:33)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '291st (10:32)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '505th (195 lbs)',
#   'Weight Lifted': 'Weight lifted: 195 lbs.',
#   'Height': '157 cm ',
#   'Weight': ' 57 kg'},
#  {'First Name': 'Rebecca',
#   'Last Name': 'Fuselier',
#   'Placing': 133,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 21,
#   'Affiliate': 'CrossFit Bolt',
#   'Height and Weight': '62 in | 125 lb',
#   'Points': 1668,
#   '21.1 Scores': '110th (13:43)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '853rd (11:49)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '23rd (8:45)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '682nd (191 lbs)',
#   'Weight Lifted': 'Weight lifted: 191 lbs.',
#   'Height': '62 in ',
#   'Weight': ' 125 lb'},
#  {'First Name': 'Meg',
#   'Last Name': 'Garrett',
#   'Placing': 138,
#   'Country': 'Canada',
#   'Continent': 'North America',
#   'Age': 38,
#   'Affiliate': 'CrossFit Crosscheck',
#   'Height and Weight': '177 cm | 160 lb',
#   'Points': 1707,
#   '21.1 Scores': '296th (14:42)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '958th (11:55)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '434th (11:07)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '19th (225 lbs)',
#   'Weight Lifted': 'Weight lifted: 225 lbs.',
#   'Height': '177 cm ',
#   'Weight': ' 160 lb'},
#  {'First Name': 'Lidia',
#   'Last Name': 'Bartoszewicz',
#   'Placing': 144,
#   'Country': 'Germany',
#   'Continent': 'Europe',
#   'Age': 28,
#   'Affiliate': 'CrossFit Bergisch Gladbach',
#   'Height and Weight': '168 cm | 63 kg',
#   'Points': 1748,
#   '21.1 Scores': '196th (14:18)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '149th (10:35)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '533rd (11:25)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '870th (188 lbs)',
#   'Weight Lifted': 'Weight lifted: 188 lbs.',
#   'Height': '168 cm ',
#   'Weight': ' 63 kg'},
#  {'First Name': 'Laurie',
#   'Last Name': 'Pfleiderer',
#   'Placing': 150,
#   'Country': 'Canada',
#   'Continent': 'North America',
#   'Age': 31,
#   'Affiliate': 'CrossFit St-Jean',
#   'Height and Weight': '157 cm | 140 lb',
#   'Points': 1787,
#   '21.1 Scores': '102nd (13:36)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '456th (11:17)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '298th (10:34)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '931st (187 lbs)',
#   'Weight Lifted': 'Weight lifted: 187 lbs.',
#   'Height': '157 cm ',
#   'Weight': ' 140 lb'},
#  {'First Name': 'Katelyn',
#   'Last Name': 'Teager',
#   'Placing': 153,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 31,
#   'Affiliate': 'CrossFit Papio',
#   'Height and Weight': '67 in | 148 lb',
#   'Points': 1796,
#   '21.1 Scores': '12th (11:45)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '817th (11:47)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '632nd (11:43)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '335th (200 lbs)',
#   'Weight Lifted': 'Weight lifted: 200 lbs.',
#   'Height': '67 in ',
#   'Weight': ' 148 lb'},
#  {'First Name': 'Jaime',
#   'Last Name': 'Goodwin',
#   'Placing': 153,
#   'Country': 'New Zealand',
#   'Continent': 'Oceania',
#   'Age': 28,
#   'Affiliate': 'CrossFit Melbourne',
#   'Height and Weight': '156 cm | 57 kg',
#   'Points': 1796,
#   '21.1 Scores': '39th (12:56)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '149th (10:35)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '81st (9:20)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '1527th (181 lbs)',
#   'Weight Lifted': 'Weight lifted: 181 lbs.',
#   'Height': '156 cm ',
#   'Weight': ' 57 kg'},
#  {'First Name': 'Hannah',
#   'Last Name': 'Frakes',
#   'Placing': 157,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 26,
#   'Affiliate': 'CrossFit Fireside',
#   'Height and Weight': '65 in | 144 lb',
#   'Points': 1835,
#   '21.1 Scores': '174th (14:08)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '318th (11:01)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '829th (12:13)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '514th (195 lbs)',
#   'Weight Lifted': 'Weight lifted: 195 lbs.',
#   'Height': '65 in ',
#   'Weight': ' 144 lb'},
#  {'First Name': 'Ashley',
# ...
#   'Weight Lifted': 'Weight lifted: 65 lbs.',
#   'Height': '63 in ',
#   'Weight': ' 130 lb'},
#  {'First Name': 'Katelyn',
#   'Last Name': 'Hunt Lawrence',
#   'Placing': 92340,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 28,
#   'Affiliate': 'Soul City CrossFit',
#   'Height and Weight': '68 in | 160 lb',
#   'Points': 335863,
#   '21.1 Scores': '91537th (13:26 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88206th (10:48 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '78666th (9:11 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '77454th (85 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 85 lbs.',
#   'Height': '68 in ',
#   'Weight': ' 160 lb'},
#  {'First Name': 'Afroditi',
#   'Last Name': 'Fragkouli',
#   'Placing': 92398,
#   'Country': 'Greece',
#   'Continent': 'Europe',
#   'Age': 44,
#   'Affiliate': 'CrossFit Piraeus',
#   'Height and Weight': '165 cm | 62 kg',
#   'Points': 336018,
#   '21.1 Scores': '91182nd (9:50 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88726th (14:17 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '76529th (6:14 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '79581st (35 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 35 lbs.',
#   'Height': '165 cm ',
#   'Weight': ' 62 kg'},
#  {'First Name': 'Yvonne',
#   'Last Name': 'Alt',
#   'Placing': 92431,
#   'Country': 'Germany',
#   'Continent': 'Europe',
#   'Age': 43,
#   'Affiliate': 'Ikigai CrossFit',
#   'Height and Weight': '169 cm | 53 kg',
#   'Points': 336101,
#   '21.1 Scores': '91596th (13:46 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88066th (9:21 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '77882nd (8:07 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '78557th (66 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 66 lbs.',
#   'Height': '169 cm ',
#   'Weight': ' 53 kg'},
#  {'First Name': 'Elke',
#   'Last Name': 'Fuhrmann',
#   'Placing': 92510,
#   'Country': 'Germany',
#   'Continent': 'Europe',
#   'Age': 46,
#   'Affiliate': 'CrossFit Heilbronn',
#   'Height and Weight': '160 cm | 58 kg',
#   'Points': 336323,
#   '21.1 Scores': '91422nd (12:46 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88642nd (13:47 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '76993rd (6:59 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '79266th (51 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 51 lbs.',
#   'Height': '160 cm ',
#   'Weight': ' 58 kg'},
#  {'First Name': 'Lucy',
#   'Last Name': 'Sirvinskas',
#   'Placing': 92535,
#   'Country': 'United Kingdom',
#   'Continent': 'Europe',
#   'Age': 26,
#   'Affiliate': 'CrossFit Leyland',
#   'Height and Weight': '160 in | 56 kg',
#   'Points': 336391,
#   '21.1 Scores': '91526th (13:23 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88593rd (13:28 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '76929th (6:54 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '79343rd (48 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 48 lbs.',
#   'Height': '160 in ',
#   'Weight': ' 56 kg'},
#  {'First Name': 'Maria',
#   'Last Name': 'Papankova',
#   'Placing': 92541,
#   'Country': 'Slovakia',
#   'Continent': 'Europe',
#   'Age': 29,
#   'Affiliate': 'CrossFit Trnava',
#   'Height and Weight': '160 cm | 50 kg',
#   'Points': 336405,
#   '21.1 Scores': '91254th (11:14 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88068th (9:22 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '77246th (7:20 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '79837th (13 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 13 lbs.',
#   'Height': '160 cm ',
#   'Weight': ' 50 kg'},
#  {'First Name': 'Crissy',
#   'Last Name': 'Broyles',
#   'Placing': 92557,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 51,
#   'Affiliate': 'St. Helena CrossFit',
#   'Height and Weight': '62 in | 128 lb',
#   'Points': 336446,
#   '21.1 Scores': '91371st (12:22 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88667th (13:55 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '77347th (7:27 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '79061st (55 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 55 lbs.',
#   'Height': '62 in ',
#   'Weight': ' 128 lb'},
#  {'First Name': 'Sally',
#   'Last Name': 'Foster',
#   'Placing': 92580,
#   'Country': 'United Kingdom',
#   'Continent': 'Europe',
#   'Age': 33,
#   'Affiliate': 'CrossFit Leyland',
#   'Height and Weight': '62 in | 175 lb',
#   'Points': 336501,
#   '21.1 Scores': '91819th (14:51 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88466th (12:39 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '77932nd (8:10 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '78284th (71 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 71 lbs.',
#   'Height': '62 in ',
#   'Weight': ' 175 lb'},
#  {'First Name': 'Brí',
#   'Last Name': 'Greene',
#   'Placing': 92597,
#   'Country': 'Ireland',
#   'Continent': 'Europe',
#   'Age': 43,
#   'Affiliate': 'CrossFit Thurles',
#   'Height and Weight': '175 cm | 67 kg',
#   'Points': 336525,
#   '21.1 Scores': '91334th (12:03 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88378th (12:05 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '78245th (8:36 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '78568th (66 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 66 lbs.',
#   'Height': '175 cm ',
#   'Weight': ' 67 kg'},
#  {'First Name': 'Karen',
#   'Last Name': 'Brown',
#   'Placing': 92683,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 48,
#   'Affiliate': 'CrossFit Flower Mound',
#   'Height and Weight': '64 in | 138 lb',
#   'Points': 336728,
#   '21.1 Scores': '91758th (14:35 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88736th (14:20 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '76651st (6:28 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '79583rd (35 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 35 lbs.',
#   'Height': '64 in ',
#   'Weight': ' 138 lb'},
#  {'First Name': 'Natalia',
#   'Last Name': 'Albuquerque',
#   'Placing': 92713,
#   'Country': 'Brazil',
#   'Continent': 'South America',
#   'Age': 28,
#   'Affiliate': 'FFD CrossFit',
#   'Height and Weight': '174 cm | 58 kg',
#   'Points': 336832,
#   '21.1 Scores': '91826th (14:52 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88620th (13:39 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '77013th (7:01 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '79373rd (45 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 45 lbs.',
#   'Height': '174 cm ',
#   'Weight': ' 58 kg'},
#  {'First Name': 'Jamie',
#   'Last Name': 'King',
#   'Placing': 92728,
#   'Country': 'United Kingdom',
#   'Continent': 'Europe',
#   'Age': 34,
#   'Affiliate': 'CrossFit Dire Wolf',
#   'Height and Weight': '162 cm | 56 kg',
#   'Points': 336863,
#   '21.1 Scores': '91530th (13:25 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88402nd (12:13 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '77136th (7:11 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '79795th (17 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 17 lbs.',
#   'Height': '162 cm ',
#   'Weight': ' 56 kg'},
#  {'First Name': 'Ailsa',
#   'Last Name': 'Birchenough',
#   'Placing': 92773,
#   'Country': 'United Kingdom',
#   'Continent': 'Europe',
#   'Age': 40,
#   'Affiliate': 'CrossFit Altrincham',
#   'Height and Weight': '170 cm | 136 lb',
#   'Points': 337001,
#   '21.1 Scores': '91417th (12:41 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88593rd (13:28 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '77399th (7:32 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '79592nd (35 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 35 lbs.',
#   'Height': '170 cm ',
#   'Weight': ' 136 lb'},
#  {'First Name': 'Lauren',
#   'Last Name': 'Kaiser',
#   'Placing': 92792,
#   'Country': 'Canada',
#   'Continent': 'North America',
#   'Age': 21,
#   'Affiliate': 'CrossFit Actuate',
#   'Height and Weight': '62 in | 116 lb',
#   'Points': 337069,
#   '21.1 Scores': '91472nd (13:04 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88791st (14:38 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '77903rd (8:08 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '78903rd (60 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 60 lbs.',
#   'Height': '62 in ',
#   'Weight': ' 116 lb'},
#  {'First Name': 'Heidi',
#   'Last Name': 'Maxwell',
#   'Placing': 92817,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 49,
#   'Affiliate': 'True Spirit CrossFit',
#   'Height and Weight': '64 in | 190 lb',
#   'Points': 337126,
#   '21.1 Scores': '91813th (14:49 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88185th (10:36 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '77838th (8:04 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '79290th (50 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 50 lbs.',
#   'Height': '64 in ',
#   'Weight': ' 190 lb'},
#  {'First Name': 'Alessandra',
#   'Last Name': 'Pereira',
#   'Placing': 92846,
#   'Country': 'Brazil',
#   'Continent': 'South America',
#   'Age': 38,
#   'Affiliate': 'CrossFit Cachoeiro',
#   'Height and Weight': '159 cm | 59 kg',
#   'Points': 337203,
#   '21.1 Scores': '91495th (13:11 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88728th (14:18 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '79046th (9:53 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '77934th (77 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 77 lbs.',
#   'Height': '159 cm ',
#   'Weight': ' 59 kg'},
#  {'First Name': 'Brandi',
#   'Last Name': 'Wood',
#   'Placing': 93016,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 54,
#   'Affiliate': 'Iron Springs CrossFit',
#   'Height and Weight': '63 in | 135 lb',
#   'Points': 337662,
#   '21.1 Scores': '91200th (10:20 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '89212th (17:18 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '78329th (8:43 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '78921st (60 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 60 lbs.',
#   'Height': '63 in ',
#   'Weight': ' 135 lb'},
#  {'First Name': 'Veronika',
#   'Last Name': 'Kassayová',
#   'Placing': 93184,
#   'Country': 'Slovakia',
#   'Continent': 'Europe',
#   'Age': 39,
#   'Affiliate': 'CrossFit Proton',
#   'Height and Weight': '180 in | 68 kg',
#   'Points': 338133,
#   '21.1 Scores': '91530th (13:25 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88836th (14:53 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '78116th (8:25 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '79651st (33 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 33 lbs.',
#   'Height': '180 in ',
#   'Weight': ' 68 kg'},
#  {'First Name': 'Sophia',
#   'Last Name': 'Thomas',
#   'Placing': 93330,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 36,
#   'Affiliate': 'Rose City CrossFit',
#   'Height and Weight': '64 in | 142 lb',
#   'Points': 338486,
#   '21.1 Scores': '91162nd (9:10 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '89157th (16:51 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '79990th (13:38 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '78177th (75 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 75 lbs.',
#   'Height': '64 in ',
#   'Weight': ' 142 lb'},
#  {'First Name': 'Kimberly',
#   'Last Name': 'Wong',
#   'Placing': 93335,
#   'Country': 'Canada',
#   'Continent': 'North America',
#   'Age': 32,
#   'Affiliate': 'CrossFit Green',
#   'Height and Weight': '65 in | 150 lb',
#   'Points': 338502,
#   '21.1 Scores': '91409th (12:36 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88695th (14:05 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '78599th (9:05 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '79799th (17 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 17 lbs.',
#   'Height': '65 in ',
#   'Weight': ' 150 lb'},
#  {'First Name': 'Mandy-Leigh',
#   'Last Name': 'Hackart',
#   'Placing': 93409,
#   'Country': 'Australia',
#   'Continent': 'Oceania',
#   'Age': 36,
#   'Affiliate': 'CrossFit 4504',
#   'Height and Weight': '159 cm | 63 kg',
#   'Points': 338665,
#   '21.1 Scores': '91515th (13:18 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88575th (13:19 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '78821st (9:27 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '79754th (22 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 22 lbs.',
#   'Height': '159 cm ',
#   'Weight': ' 63 kg'},
#  {'First Name': 'Charlotte',
#   'Last Name': 'Cox',
#   'Placing': 93427,
#   'Country': 'United Kingdom',
#   'Continent': 'Europe',
#   'Age': 33,
#   'Affiliate': 'CrossFit Leyland',
#   'Height and Weight': '164 cm | 66 kg',
#   'Points': 338692,
#   '21.1 Scores': '91602nd (13:47 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88404th (12:14 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '79031st (9:51 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '79655th (33 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 33 lbs.',
#   'Height': '164 cm ',
#   'Weight': ' 66 kg'},
#  {'First Name': 'Birgit',
#   'Last Name': 'Baldauf',
#   'Placing': 93497,
#   'Country': 'Germany',
#   'Continent': 'Europe',
#   'Age': 46,
#   'Affiliate': 'CrossFit Rhein-Neckar',
#   'Height and Weight': '173 cm | 67 kg',
#   'Points': 338850,
#   '21.1 Scores': '91588th (13:43 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88323rd (11:41 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '79003rd (9:48 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '79936th (1 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 1 lbs.',
#   'Height': '173 cm ',
#   'Weight': ' 67 kg'},
#  {'First Name': 'Victoria',
#   'Last Name': 'Michel',
#   'Placing': 93516,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 34,
#   'Affiliate': 'CrossFit Stony Brook',
#   'Height and Weight': '69 in | 145 lb',
#   'Points': 338892,
#   '21.1 Scores': '91165th (9:23 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88152nd (10:24 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '79945th (13:14 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '79630th (35 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 35 lbs.',
#   'Height': '69 in ',
#   'Weight': ' 145 lb'},
#  {'First Name': 'Laetitia',
#   'Last Name': 'Decraene',
#   'Placing': 93907,
#   'Country': 'France',
#   'Continent': 'Europe',
#   'Age': 35,
#   'Affiliate': 'MKB CrossFit',
#   'Height and Weight': '170 cm | 69 kg',
#   'Points': 339829,
#   '21.1 Scores': '91360th (12:17 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '89232nd (17:28 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '79392nd (10:40 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '79845th (13 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 13 lbs.',
#   'Height': '170 cm ',
#   'Weight': ' 69 kg'},
#  {'First Name': 'Sille',
#   'Last Name': 'Vaiksaar',
#   'Placing': 93996,
#   'Country': 'Estonia',
#   'Continent': 'Europe',
#   'Age': 37,
#   'Affiliate': 'CrossFit Tartu',
#   'Height and Weight': '174 cm | 68 kg',
#   'Points': 340095,
#   '21.1 Scores': '91749th (14:32 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88558th (13:14 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '79979th (13:31 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '79809th (16 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 16 lbs.',
#   'Height': '174 cm ',
#   'Weight': ' 68 kg'},
#  {'First Name': 'Maria',
#   'Last Name': 'Wheeler',
#   'Placing': 95263,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 54,
#   'Affiliate': 'Wild Horizons CrossFit',
#   'Height and Weight': '63 in | 157 lb',
#   'Points': 344295,
#   '21.1 Scores': '91725th (14:25 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88988th (15:49 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '79071st (9:56 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '84511th (0 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 0 lbs.',
#   'Height': '63 in ',
#   'Weight': ' 157 lb'},
#  {'First Name': 'Stella',
#   'Last Name': 'Richards',
#   'Placing': 100421,
#   'Country': 'United States',
#   'Continent': 'North America',
#   'Age': 17,
#   'Affiliate': 'Badger CrossFit',
#   'Height and Weight': '67 in | 140 lb',
#   'Points': 356203,
#   '21.1 Scores': '91795th (14:44 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88760th (14:29 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '78698th (9:14 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '96950th (0 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 0 lbs.',
#   'Height': '67 in ',
#   'Weight': ' 140 lb'},
#  {'First Name': 'Sarah',
#   'Last Name': 'Carter',
#   'Placing': 102710,
#   'Country': 'United Kingdom',
#   'Continent': 'Europe',
#   'Age': 35,
#   'Affiliate': 'CW1 CrossFit',
#   'Height and Weight': '168 cm | 59 kg',
#   'Points': 361337,
#   '21.1 Scores': '91650th (14:04 - f)',
#   '21.1 Reps': 605,
#   '21.2 Scores': '88356th (11:55 - f)',
#   '21.2 Reps': 225,
#   '21.3 Scores': '76824th (6:45 - f)',
#   '21.3 Reps': 180,
#   '21.4 Scores': '104507th (0 lbs - f)',
#   'Weight Lifted': 'Weight lifted: 0 lbs.',
#   'Height': '168 cm ',
#   'Weight': ' 59 kg'}]

# %%
from pymongo import MongoClient

# %%
mongo = MongoClient(port=27017)

# %%
db = mongo.CrossFitDB
CrossFitData = db.CrossFitData

# %%
CrossFitData.insert_many(crossfitDicts)

# %%
results = list(CrossFitData.find())

# %%
for order in results:
    pprint(order)
# Out:
# {'21.1 Reps': 605,
#  '21.1 Scores': '6th (11:21)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '11th (9:26)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '1st (7:37)',
#  '21.4 Scores': '8th (230 lbs)',
#  'Affiliate': 'CrossFit East Nashville',
#  'Age': 27,
#  'Continent': 'Oceania',
#  'Country': 'Australia',
#  'First Name': 'Tia-Clair',
#  'Height': '163 cm ',
#  'Height and Weight': '163 cm | 58 kg',
#  'Last Name': 'Toomey',
#  'Placing': 1,
#  'Points': 26,
#  'Weight': ' 58 kg',
#  'Weight Lifted': 'Weight lifted: 230 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0a9')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '14th (11:48)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '1st (8:51)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '14th (8:28)',
#  '21.4 Scores': '37th (218 lbs)',
#  'Affiliate': 'Perform Overcome Excel CrossFit',
#  'Age': 17,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Emma',
#  'Height': '64 in ',
#  'Height and Weight': '64 in | 140 lb',
#  'Last Name': 'Cary',
#  'Placing': 2,
#  'Points': 66,
#  'Weight': ' 140 lb',
#  'Weight Lifted': 'Weight lifted: 218 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0aa')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '63rd (13:11)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '23rd (9:42)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '20th (8:41)',
#  '21.4 Scores': '5th (232 lbs)',
#  'Affiliate': 'CrossFit Carv',
#  'Age': 31,
#  'Continent': 'Oceania',
#  'Country': 'Australia',
#  'First Name': 'Kara',
#  'Height': '162 cm ',
#  'Height and Weight': '162 cm | 158 lb',
#  'Last Name': 'Saunders',
#  'Placing': 3,
#  'Points': 111,
#  'Weight': ' 158 lb',
#  'Weight Lifted': 'Weight lifted: 232 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0ab')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '121st (13:47)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '21st (9:41)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '4th (7:47)',
#  '21.4 Scores': '43rd (217 lbs)',
#  'Affiliate': 'CrossFit Polaris',
#  'Age': 32,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Kristi Eramo',
#  'Height': '62 in ',
#  'Height and Weight': '62 in | 132 lb',
#  'Last Name': "O'Connell",
#  'Placing': 4,
#  'Points': 189,
#  'Weight': ' 132 lb',
#  'Weight Lifted': 'Weight lifted: 217 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0ac')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '4th (11:06)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '163rd (10:38)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '2nd (7:38)',
#  '21.4 Scores': '42nd (217 lbs)',
#  'Affiliate': 'Lion Brave CrossFit',
#  'Age': 17,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Mallory',
#  'Height': '63 in ',
#  'Height and Weight': '63 in | 145 lb',
#  'Last Name': "O'Brien",
#  'Placing': 5,
#  'Points': 211,
#  'Weight': ' 145 lb',
#  'Weight Lifted': 'Weight lifted: 217 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0ad')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '171st (14:07)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '9th (9:24)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '27th (8:46)',
#  '21.4 Scores': '25th (224 lbs)',
#  'Affiliate': 'Boundary CrossFit',
#  'Age': 31,
#  'Continent': 'Europe',
#  'Country': 'Ireland',
#  'First Name': 'Emma',
#  'Height': '165 cm ',
#  'Height and Weight': '165 cm | 64 kg',
#  'Last Name': 'Mcquaid',
#  'Placing': 6,
#  'Points': 232,
#  'Weight': ' 64 kg',
#  'Weight Lifted': 'Weight lifted: 224 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0ae')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '114th (13:44)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '83rd (10:16)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '37th (9:00)',
#  '21.4 Scores': '4th (236 lbs)',
#  'Affiliate': 'CrossFit Invictus',
#  'Age': 27,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Dani',
#  'Height': '66 in ',
#  'Height and Weight': '66 in | 168 lb',
#  'Last Name': 'Speegle',
#  'Placing': 7,
#  'Points': 238,
#  'Weight': ' 168 lb',
#  'Weight Lifted': 'Weight lifted: 236 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0af')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '26th (12:22)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '97th (10:21)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '18th (8:40)',
#  '21.4 Scores': '102nd (211 lbs)',
#  'Affiliate': 'CrossFit Trivium',
#  'Age': 26,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Brooke',
#  'Height': '66 in ',
#  'Height and Weight': '66 in | 150 lb',
#  'Last Name': 'Wells',
#  'Placing': 9,
#  'Points': 243,
#  'Weight': ' 150 lb',
#  'Weight Lifted': 'Weight lifted: 211 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0b0')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '8th (11:33)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '34th (9:50)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '5th (7:52)',
#  '21.4 Scores': '260th (202 lbs)',
#  'Affiliate': 'CrossFit Mayhem',
#  'Age': 20,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Haley',
#  'Height': '67 in ',
#  'Height and Weight': '67 in | 140 lb',
#  'Last Name': 'Adams',
#  'Placing': 10,
#  'Points': 307,
#  'Weight': ' 140 lb',
#  'Weight Lifted': 'Weight lifted: 202 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0b1')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '12th (11:45)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '31st (9:48)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '28th (8:48)',
#  '21.4 Scores': '249th (203 lbs)',
#  'Affiliate': 'CrossFit Trondheim',
#  'Age': 25,
#  'Continent': 'Europe',
#  'Country': 'Norway',
#  'First Name': 'Matilde',
#  'Height': '174 cm ',
#  'Height and Weight': '174 cm | 68 kg',
#  'Last Name': 'Garnes',
#  'Placing': 11,
#  'Points': 320,
#  'Weight': ' 68 kg',
#  'Weight Lifted': 'Weight lifted: 203 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0b2')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '174th (14:08)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '7th (9:18)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '120th (9:41)',
#  '21.4 Scores': '29th (221 lbs)',
#  'Affiliate': 'C23 CrossFit',
#  'Age': 22,
#  'Continent': 'Europe',
#  'Country': 'Poland',
#  'First Name': 'Gabriela',
#  'Height': '170 cm ',
#  'Height and Weight': '170 cm | 75 kg',
#  'Last Name': 'Migała',
#  'Placing': 12,
#  'Points': 330,
#  'Weight': ' 75 kg',
#  'Weight Lifted': 'Weight lifted: 221 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0b3')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '3rd (11:05)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '190th (10:43)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '64th (9:11)',
#  '21.4 Scores': '106th (210 lbs)',
#  'Affiliate': 'CrossFit Culmination',
#  'Age': 25,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Danielle',
#  'Height': '170 cm ',
#  'Height and Weight': '170 cm | 150 lb',
#  'Last Name': 'Brandon',
#  'Placing': 13,
#  'Points': 363,
#  'Weight': ' 150 lb',
#  'Weight Lifted': 'Weight lifted: 210 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0b4')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '29th (12:30)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '63rd (10:08)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '109th (9:36)',
#  '21.4 Scores': '175th (206 lbs)',
#  'Affiliate': 'CrossFit New England',
#  'Age': 28,
#  'Continent': 'Europe',
#  'Country': 'Iceland',
#  'First Name': 'Katrin Tanja',
#  'Height': '169 cm ',
#  'Height and Weight': '169 cm | 150 lb',
#  'Last Name': 'Davidsdottir',
#  'Placing': 14,
#  'Points': 376,
#  'Weight': ' 150 lb',
#  'Weight Lifted': 'Weight lifted: 206 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0b5')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '52nd (13:05)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '21st (9:41)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '6th (7:56)',
#  '21.4 Scores': '319th (200 lbs)',
#  'Affiliate': 'CrossFit Culmination',
#  'Age': 32,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Kari',
#  'Height': '63 in ',
#  'Height and Weight': '63 in | 139 lb',
#  'Last Name': 'Pearce',
#  'Placing': 16,
#  'Points': 398,
#  'Weight': ' 139 lb',
#  'Weight Lifted': 'Weight lifted: 200 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0b6')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '19th (12:02)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '2nd (8:58)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '10th (8:10)',
#  '21.4 Scores': '383rd (198 lbs)',
#  'Affiliate': 'CrossFit Oslo',
#  'Age': 35,
#  'Continent': 'Europe',
#  'Country': 'Norway',
#  'First Name': 'Kristin',
#  'Height': '162 cm ',
#  'Height and Weight': '162 cm | 59 kg',
#  'Last Name': 'Holte',
#  'Placing': 17,
#  'Points': 414,
#  'Weight': ' 59 kg',
#  'Weight Lifted': 'Weight lifted: 198 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0b7')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '296th (14:42)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '17th (9:35)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '40th (9:01)',
#  '21.4 Scores': '105th (210 lbs)',
#  'Affiliate': 'CrossFit Floripa',
#  'Age': 24,
#  'Continent': 'South America',
#  'Country': 'Brazil',
#  'First Name': 'Amanda',
#  'Height': '153 cm ',
#  'Height and Weight': '153 cm | 56 kg',
#  'Last Name': 'Fusuma',
#  'Placing': 18,
#  'Points': 458,
#  'Weight': ' 56 kg',
#  'Weight Lifted': 'Weight lifted: 210 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0b8')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '325th (14:48)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '61st (10:06)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '46th (9:04)',
#  '21.4 Scores': '28th (221 lbs)',
#  'Affiliate': 'CrossFit Mayhem',
#  'Age': 32,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Andrea',
#  'Height': '66 in ',
#  'Height and Weight': '66 in | 154 lb',
#  'Last Name': 'Nisler',
#  'Placing': 19,
#  'Points': 460,
#  'Weight': ' 154 lb',
#  'Weight Lifted': 'Weight lifted: 221 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0b9')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '196th (14:18)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '99th (10:23)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '152nd (9:54)',
#  '21.4 Scores': '16th (225 lbs)',
#  'Affiliate': 'CrossFit New England',
#  'Age': 29,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Amanda',
#  'Height': '67 in ',
#  'Height and Weight': '67 in | 160 lb',
#  'Last Name': 'Barnhart',
#  'Placing': 20,
#  'Points': 463,
#  'Weight': ' 160 lb',
#  'Weight Lifted': 'Weight lifted: 225 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0ba')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '121st (13:47)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '46th (10:00)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '3rd (7:40)',
#  '21.4 Scores': '294th (201 lbs)',
#  'Affiliate': 'CrossFit Culmination',
#  'Age': 27,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Bethany',
#  'Height': '64 in ',
#  'Height and Weight': '64 in | 144 lb',
#  'Last Name': 'Shadburne',
#  'Placing': 21,
#  'Points': 464,
#  'Weight': ' 144 lb',
#  'Weight Lifted': 'Weight lifted: 201 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0bb')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '28th (12:25)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '171st (10:40)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '18th (8:40)',
#  '21.4 Scores': '262nd (202 lbs)',
#  'Affiliate': 'CrossFit Pro1',
#  'Age': 29,
#  'Continent': 'North America',
#  'Country': 'Canada',
#  'First Name': 'Chloe',
#  'Height': '67 in ',
#  'Height and Weight': '67 in | 146 lb',
#  'Last Name': 'Gauvin-David',
#  'Placing': 22,
#  'Points': 479,
#  'Weight': ' 146 lb',
#  'Weight Lifted': 'Weight lifted: 202 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0bc')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '260th (14:34)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '91st (10:19)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '16th (8:34)',
#  '21.4 Scores': '131st (208 lbs)',
#  'Affiliate': 'Cavaleiros CrossFit',
#  'Age': 30,
#  'Continent': 'South America',
#  'Country': 'Brazil',
#  'First Name': 'Larissa',
#  'Height': '153 cm ',
#  'Height and Weight': '153 cm | 62 kg',
#  'Last Name': 'Cunha',
#  'Placing': 23,
#  'Points': 498,
#  'Weight': ' 62 kg',
#  'Weight Lifted': 'Weight lifted: 208 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0bd')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '284th (14:39)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '99th (10:23)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '50th (9:06)',
#  '21.4 Scores': '89th (212 lbs)',
#  'Affiliate': 'Ocean State CrossFit',
#  'Age': 33,
#  'Continent': 'North America',
#  'Country': 'Canada',
#  'First Name': 'Amy',
#  'Height': '163 cm ',
#  'Height and Weight': '163 cm | 154 lb',
#  'Last Name': 'Morton',
#  'Placing': 24,
#  'Points': 522,
#  'Weight': ' 154 lb',
#  'Weight Lifted': 'Weight lifted: 212 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0be')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '89th (13:29)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '119th (10:29)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '37th (9:00)',
#  '21.4 Scores': '322nd (200 lbs)',
#  'Affiliate': 'CrossFit 514',
#  'Age': 33,
#  'Continent': 'North America',
#  'Country': 'Canada',
#  'First Name': 'Carol-Ann',
#  'Height': '164 cm ',
#  'Height and Weight': '164 cm | 142 lb',
#  'Last Name': 'Reason-Thibault',
#  'Placing': 28,
#  'Points': 567,
#  'Weight': ' 142 lb',
#  'Weight Lifted': 'Weight lifted: 200 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0bf')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '31st (12:39)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '59th (10:05)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '98th (9:32)',
#  '21.4 Scores': '385th (198 lbs)',
#  'Affiliate': 'CrossFit Zug',
#  'Age': 29,
#  'Continent': 'Europe',
#  'Country': 'Iceland',
#  'First Name': 'Thuridur Erla',
#  'Height': '164 cm ',
#  'Height and Weight': '164 cm | 59 kg',
#  'Last Name': 'Helgadottir',
#  'Placing': 29,
#  'Points': 573,
#  'Weight': ' 59 kg',
#  'Weight Lifted': 'Weight lifted: 198 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0c0')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '269th (14:36)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '20th (9:38)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '36th (8:56)',
#  '21.4 Scores': '263rd (202 lbs)',
#  'Affiliate': 'CrossFit Undivided',
#  'Age': 31,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Kristine',
#  'Height': '63 in ',
#  'Height and Weight': '63 in | 138 lb',
#  'Last Name': 'Best',
#  'Placing': 30,
#  'Points': 588,
#  'Weight': ' 138 lb',
#  'Weight Lifted': 'Weight lifted: 202 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0c1')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '126th (13:48)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '42nd (9:57)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '220th (10:15)',
#  '21.4 Scores': '250th (203 lbs)',
#  'Affiliate': 'Plus64 CrossFit',
#  'Age': 27,
#  'Continent': 'Oceania',
#  'Country': 'New Zealand',
#  'First Name': 'Madeline',
#  'Height': '165 cm ',
#  'Height and Weight': '165 cm | 69 kg',
#  'Last Name': 'Shelling',
#  'Placing': 31,
#  'Points': 638,
#  'Weight': ' 69 kg',
#  'Weight Lifted': 'Weight lifted: 203 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0c2')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '77th (13:23)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '221st (10:49)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '327th (10:42)',
#  '21.4 Scores': '15th (226 lbs)',
#  'Affiliate': 'CrossFit Alpha Prime',
#  'Age': 26,
#  'Continent': 'Europe',
#  'Country': 'Slovakia',
#  'First Name': 'Karin',
#  'Height': '170 cm ',
#  'Height and Weight': '170 cm | 72 kg',
#  'Last Name': 'Freyová',
#  'Placing': 32,
#  'Points': 640,
#  'Weight': ' 72 kg',
#  'Weight Lifted': 'Weight lifted: 226 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0c3')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '128th (13:49)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '171st (10:40)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '161st (9:57)',
#  '21.4 Scores': '192nd (205 lbs)',
#  'Affiliate': 'CrossFit Northlake',
#  'Age': 33,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Mekenzie',
#  'Height': '64 in ',
#  'Height and Weight': '64 in | 155 lb',
#  'Last Name': 'Riley',
#  'Placing': 33,
#  'Points': 652,
#  'Weight': ' 155 lb',
#  'Weight Lifted': 'Weight lifted: 205 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0c4')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '102nd (13:36)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '81st (10:15)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '50th (9:06)',
#  '21.4 Scores': '422nd (197 lbs)',
#  'Affiliate': '12th State CrossFit',
#  'Age': 21,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Shelby',
#  'Height': '62 in ',
#  'Height and Weight': '62 in | 135 lb',
#  'Last Name': 'Neal',
#  'Placing': 34,
#  'Points': 655,
#  'Weight': ' 135 lb',
#  'Weight Lifted': 'Weight lifted: 197 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0c5')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '360th (14:54)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '24th (9:43)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '13th (8:21)',
#  '21.4 Scores': '261st (202 lbs)',
#  'Affiliate': 'C23 CrossFit',
#  'Age': 29,
#  'Continent': 'Europe',
#  'Country': 'Norway',
#  'First Name': 'Jacqueline',
#  'Height': '167 cm ',
#  'Height and Weight': '167 cm | 67 kg',
#  'Last Name': 'Dahlstrøm',
#  'Placing': 35,
#  'Points': 658,
#  'Weight': ' 67 kg',
#  'Weight Lifted': 'Weight lifted: 202 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0c6')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '181st (14:11)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '382nd (11:08)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '44th (9:03)',
#  '21.4 Scores': '59th (215 lbs)',
#  'Affiliate': 'Rockwell CrossFit',
#  'Age': 35,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Mandi',
#  'Height': '65 in ',
#  'Height and Weight': '65 in | 150 lb',
#  'Last Name': 'Janowitz',
#  'Placing': 37,
#  'Points': 666,
#  'Weight': ' 150 lb',
#  'Weight Lifted': 'Weight lifted: 215 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0c7')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '148th (13:57)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '43rd (9:58)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '71st (9:13)',
#  '21.4 Scores': '423rd (197 lbs)',
#  'Affiliate': 'CrossFit Vertex',
#  'Age': 29,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Paige',
#  'Height': '63 in ',
#  'Height and Weight': '63 in | 143 lb',
#  'Last Name': 'Semenza',
#  'Placing': 39,
#  'Points': 685,
#  'Weight': ' 143 lb',
#  'Weight Lifted': 'Weight lifted: 197 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0c8')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '235th (14:28)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '125th (10:30)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '114th (9:39)',
#  '21.4 Scores': '242nd (204 lbs)',
#  'Affiliate': 'CrossFit Karlstad',
#  'Age': 29,
#  'Continent': 'Europe',
#  'Country': 'Sweden',
#  'First Name': 'Emma',
#  'Height': '168 cm ',
#  'Height and Weight': '168 cm | 68 kg',
#  'Last Name': 'Tall',
#  'Placing': 42,
#  'Points': 716,
#  'Weight': ' 68 kg',
#  'Weight Lifted': 'Weight lifted: 204 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0c9')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '208th (14:21)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '420th (11:13)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '98th (9:32)',
#  '21.4 Scores': '10th (228 lbs)',
#  'Affiliate': 'CrossFit Dixie',
#  'Age': 23,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Kloie',
#  'Height': '67 in ',
#  'Height and Weight': '67 in | 155 lb',
#  'Last Name': 'Wilson',
#  'Placing': 44,
#  'Points': 736,
#  'Weight': ' 155 lb',
#  'Weight Lifted': 'Weight lifted: 228 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0ca')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '57th (13:09)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '312th (11:00)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '50th (9:06)',
#  '21.4 Scores': '324th (200 lbs)',
#  'Affiliate': 'CrossFit FFA',
#  'Age': 33,
#  'Continent': 'Europe',
#  'Country': 'Italy',
#  'First Name': 'Antea',
#  'Height': '160 cm ',
#  'Height and Weight': '160 cm | 60 kg',
#  'Last Name': 'Longo',
#  'Placing': 46,
#  'Points': 743,
#  'Weight': ' 60 kg',
#  'Weight Lifted': 'Weight lifted: 200 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0cb')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '110th (13:43)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '496th (11:21)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '126th (9:43)',
#  '21.4 Scores': '38th (218 lbs)',
#  'Affiliate': 'CrossFit Berrini',
#  'Age': 21,
#  'Continent': 'South America',
#  'Country': 'Brazil',
#  'First Name': 'Gabriella',
#  'Height': '163 cm ',
#  'Height and Weight': '163 cm | 62 kg',
#  'Last Name': 'Moratti',
#  'Placing': 47,
#  'Points': 770,
#  'Weight': ' 62 kg',
#  'Weight Lifted': 'Weight lifted: 218 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0cc')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '96th (13:32)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '370th (11:07)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '23rd (8:45)',
#  '21.4 Scores': '296th (201 lbs)',
#  'Affiliate': 'Reebok CrossFit Frankston',
#  'Age': 24,
#  'Continent': 'Oceania',
#  'Country': 'Australia',
#  'First Name': 'Madeline',
#  'Height': '158 cm ',
#  'Height and Weight': '158 cm | 62 kg',
#  'Last Name': 'Sturt',
#  'Placing': 48,
#  'Points': 785,
#  'Weight': ' 62 kg',
#  'Weight Lifted': 'Weight lifted: 201 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0cd')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '225th (14:26)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '99th (10:23)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '354th (10:47)',
#  '21.4 Scores': '108th (210 lbs)',
#  'Affiliate': 'CrossFit Mejeriet',
#  'Age': 28,
#  'Continent': 'Europe',
#  'Country': 'Sweden',
#  'First Name': 'Hanna',
#  'Height': '177 cm ',
#  'Height and Weight': '177 cm | 81 kg',
#  'Last Name': 'Karlsson',
#  'Placing': 49,
#  'Points': 786,
#  'Weight': ' 81 kg',
#  'Weight Lifted': 'Weight lifted: 210 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0ce')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '39th (12:56)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '209th (10:47)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '46th (9:04)',
#  '21.4 Scores': '497th (195 lbs)',
#  'Affiliate': 'CrossFit Sea Level',
#  'Age': 32,
#  'Continent': 'North America',
#  'Country': 'Canada',
#  'First Name': 'Emily',
#  'Height': '170 cm ',
#  'Height and Weight': '170 cm | 152 lb',
#  'Last Name': 'Rolfe',
#  'Placing': 50,
#  'Points': 791,
#  'Weight': ' 152 lb',
#  'Weight Lifted': 'Weight lifted: 195 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0cf')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '23rd (12:12)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '68th (10:10)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '248th (10:24)',
#  '21.4 Scores': '480th (196 lbs)',
#  'Affiliate': 'CrossFit 4740',
#  'Age': 30,
#  'Continent': 'Oceania',
#  'Country': 'Australia',
#  'First Name': 'Christee',
#  'Height': '158 cm ',
#  'Height and Weight': '158 cm | 60 kg',
#  'Last Name': 'Bishop',
#  'Placing': 51,
#  'Points': 819,
#  'Weight': ' 60 kg',
#  'Weight Lifted': 'Weight lifted: 196 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0d0')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '181st (14:11)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '602nd (11:30)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '31st (8:54)',
#  '21.4 Scores': '31st (220 lbs)',
#  'Affiliate': 'CrossFit Glasshouse',
#  'Age': 24,
#  'Continent': 'Europe',
#  'Country': 'Hungary',
#  'First Name': 'Laura',
#  'Height': '170 cm ',
#  'Height and Weight': '170 cm | 70 kg',
#  'Last Name': 'Horváth',
#  'Placing': 52,
#  'Points': 845,
#  'Weight': ' 70 kg',
#  'Weight Lifted': 'Weight lifted: 220 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0d1')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '198th (14:19)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88th (10:18)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '256th (10:25)',
#  '21.4 Scores': '303rd (201 lbs)',
#  'Affiliate': 'ESF CrossFit',
#  'Age': 17,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Olivia',
#  'Height': '65 in ',
#  'Height and Weight': '65 in | 145 lb',
#  'Last Name': 'Sulek',
#  'Placing': 52,
#  'Points': 845,
#  'Weight': ' 145 lb',
#  'Weight Lifted': 'Weight lifted: 201 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0d2')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '325th (14:48)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '239th (10:51)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '176th (10:00)',
#  '21.4 Scores': '132nd (208 lbs)',
#  'Affiliate': 'CrossFit Fraser Valley',
#  'Age': 19,
#  'Continent': 'North America',
#  'Country': 'Canada',
#  'First Name': 'Freya',
#  'Height': '165 cm ',
#  'Height and Weight': '165 cm | 67 kg',
#  'Last Name': 'Moosbrugger',
#  'Placing': 54,
#  'Points': 872,
#  'Weight': ' 67 kg',
#  'Weight Lifted': 'Weight lifted: 208 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0d3')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '216th (14:24)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '346th (11:04)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '137th (9:47)',
#  '21.4 Scores': '190th (205 lbs)',
#  'Affiliate': 'CrossFit Omnia',
#  'Age': 31,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Marykay',
#  'Height': '63 in ',
#  'Height and Weight': '63 in | 150 lb',
#  'Last Name': 'Dreisilker',
#  'Placing': 56,
#  'Points': 889,
#  'Weight': ' 150 lb',
#  'Weight Lifted': 'Weight lifted: 205 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0d4')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '284th (14:39)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '245th (10:52)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '219th (10:14)',
#  '21.4 Scores': '150th (207 lbs)',
#  'Affiliate': 'CrossFit Pro1',
#  'Age': 30,
#  'Continent': 'Europe',
#  'Country': 'France',
#  'First Name': 'Manon',
#  'Height': '163 cm ',
#  'Height and Weight': '163 cm | 145 lb',
#  'Last Name': 'Lesur',
#  'Placing': 59,
#  'Points': 898,
#  'Weight': ' 145 lb',
#  'Weight Lifted': 'Weight lifted: 207 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0d5')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '163rd (14:02)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '71st (10:11)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '298th (10:34)',
#  '21.4 Scores': '388th (198 lbs)',
#  'Affiliate': 'CrossFit Lower Mountains',
#  'Age': 31,
#  'Continent': 'Oceania',
#  'Country': 'Australia',
#  'First Name': 'Justine',
#  'Height': '163 cm ',
#  'Height and Weight': '163 cm | 140 lb',
#  'Last Name': 'Beath',
#  'Placing': 60,
#  'Points': 920,
#  'Weight': ' 140 lb',
#  'Weight Lifted': 'Weight lifted: 198 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0d6')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '198th (14:19)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '35th (9:53)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '33rd (8:55)',
#  '21.4 Scores': '683rd (191 lbs)',
#  'Affiliate': 'CrossFit Mentality',
#  'Age': 26,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Feeroozeh',
#  'Height': '62 in ',
#  'Height and Weight': '62 in | 130 lb',
#  'Last Name': 'Saghafi',
#  'Placing': 62,
#  'Points': 949,
#  'Weight': ' 130 lb',
#  'Weight Lifted': 'Weight lifted: 191 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0d7')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '397th (14:59)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '363rd (11:06)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '161st (9:57)',
#  '21.4 Scores': '39th (218 lbs)',
#  'Affiliate': 'CrossFit Up',
#  'Age': 34,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Kelly',
#  'Height': '64 in ',
#  'Height and Weight': '64 in | 145 lb',
#  'Last Name': 'Clark',
#  'Placing': 63,
#  'Points': 960,
#  'Weight': ' 145 lb',
#  'Weight Lifted': 'Weight lifted: 218 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0d8')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '32nd (12:43)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '141st (10:34)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '102nd (9:33)',
#  '21.4 Scores': '709th (190 lbs)',
#  'Affiliate': 'CrossFit Nordic',
#  'Age': 28,
#  'Continent': 'Europe',
#  'Country': 'Sweden',
#  'First Name': 'Mikaela',
#  'Height': '179 cm ',
#  'Height and Weight': '179 cm | 68 kg',
#  'Last Name': 'Norman',
#  'Placing': 64,
#  'Points': 984,
#  'Weight': ' 68 kg',
#  'Weight Lifted': 'Weight lifted: 190 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0d9')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '273rd (14:37)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '273rd (10:56)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '309th (10:37)',
#  '21.4 Scores': '153rd (207 lbs)',
#  'Affiliate': 'CrossFit Nixa',
#  'Age': 28,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Taylor',
#  'Height': '64 in ',
#  'Height and Weight': '64 in | 154 lb',
#  'Last Name': 'Rector',
#  'Placing': 65,
#  'Points': 1008,
#  'Weight': ' 154 lb',
#  'Weight Lifted': 'Weight lifted: 207 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0da')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '85th (13:27)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '190th (10:43)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '365th (10:49)',
#  '21.4 Scores': '375th (199 lbs)',
#  'Affiliate': 'Styrka CrossFit',
#  'Age': 30,
#  'Continent': 'Europe',
#  'Country': 'Sweden',
#  'First Name': 'Camilla',
#  'Height': '165 cm ',
#  'Height and Weight': '165 cm | 69 kg',
#  'Last Name': 'Salomonsson Hellman',
#  'Placing': 66,
#  'Points': 1015,
#  'Weight': ' 69 kg',
#  'Weight Lifted': 'Weight lifted: 199 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0db')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '224th (14:25)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '264th (10:55)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '234th (10:20)',
#  '21.4 Scores': '301st (201 lbs)',
#  'Affiliate': 'CrossFit Invigorate',
#  'Age': 29,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Mary Helen',
#  'Height': '64 in ',
#  'Height and Weight': '64 in | 142 lb',
#  'Last Name': 'Saunders',
#  'Placing': 67,
#  'Points': 1023,
#  'Weight': ' 142 lb',
#  'Weight Lifted': 'Weight lifted: 201 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0dc')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '42nd (12:58)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '256th (10:54)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '80th (9:19)',
#  '21.4 Scores': '684th (191 lbs)',
#  'Affiliate': 'CrossFit Roppongi',
#  'Age': 34,
#  'Continent': 'Asia',
#  'Country': 'Japan',
#  'First Name': 'Yuko',
#  'Height': '152 cm ',
#  'Height and Weight': '152 cm | 125 lb',
#  'Last Name': 'Sakuyama',
#  'Placing': 69,
#  'Points': 1062,
#  'Weight': ' 125 lb',
#  'Weight Lifted': 'Weight lifted: 191 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0dd')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '74th (13:19)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '733rd (11:41)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '69th (9:12)',
#  '21.4 Scores': '188th (205 lbs)',
#  'Affiliate': 'CrossFit Hype',
#  'Age': 20,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Kaela',
#  'Height': '61 in ',
#  'Height and Weight': '61 in | 116 lb',
#  'Last Name': 'Stephano',
#  'Placing': 70,
#  'Points': 1064,
#  'Weight': ' 116 lb',
#  'Weight Lifted': 'Weight lifted: 205 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0de')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '253rd (14:32)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '141st (10:34)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '298th (10:34)',
#  '21.4 Scores': '374th (199 lbs)',
#  'Affiliate': 'CrossFit Borgen',
#  'Age': 31,
#  'Continent': 'Europe',
#  'Country': 'Sweden',
#  'First Name': 'Emelie',
#  'Height': '162 cm ',
#  'Height and Weight': '162 cm | 68 kg',
#  'Last Name': 'Lundberg',
#  'Placing': 71,
#  'Points': 1066,
#  'Weight': ' 68 kg',
#  'Weight Lifted': 'Weight lifted: 199 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0df')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '360th (14:54)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '180th (10:41)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '111th (9:37)',
#  '21.4 Scores': '424th (197 lbs)',
#  'Affiliate': 'CrossFit 1855',
#  'Age': 29,
#  'Continent': 'North America',
#  'Country': 'Canada',
#  'First Name': 'Leigha',
#  'Height': '161 cm ',
#  'Height and Weight': '161 cm | 137 lb',
#  'Last Name': 'Dean',
#  'Placing': 73,
#  'Points': 1075,
#  'Weight': ' 137 lb',
#  'Weight Lifted': 'Weight lifted: 197 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0e0')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '151st (13:59)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '12th (9:27)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '15th (8:33)',
#  '21.4 Scores': '906th (187 lbs)',
#  'Affiliate': 'CrossFit Berea',
#  'Age': 33,
#  'Continent': 'Oceania',
#  'Country': 'New Zealand',
#  'First Name': 'Emma',
#  'Height': '62 in ',
#  'Height and Weight': '62 in | 130 lb',
#  'Last Name': 'Chapman',
#  'Placing': 75,
#  'Points': 1084,
#  'Weight': ' 130 lb',
#  'Weight Lifted': 'Weight lifted: 187 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0e1')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '149th (13:58)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '190th (10:43)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '132nd (9:46)',
#  '21.4 Scores': '616th (192 lbs)',
#  'Affiliate': 'Blues City CrossFit',
#  'Age': 30,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Taylor',
#  'Height': '66 in ',
#  'Height and Weight': '66 in | 140 lb',
#  'Last Name': 'Streid',
#  'Placing': 76,
#  'Points': 1087,
#  'Weight': ' 140 lb',
#  'Weight Lifted': 'Weight lifted: 192 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0e2')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '158th (14:01)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '590th (11:29)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '176th (10:00)',
#  '21.4 Scores': '176th (206 lbs)',
#  'Affiliate': 'CrossFit Tigran',
#  'Age': 32,
#  'Continent': 'North America',
#  'Country': 'Mexico',
#  'First Name': 'Brenda',
#  'Height': '2 cm ',
#  'Height and Weight': '2 cm | 139 lb',
#  'Last Name': 'Castro',
#  'Placing': 77,
#  'Points': 1100,
#  'Weight': ' 139 lb',
#  'Weight Lifted': 'Weight lifted: 206 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0e3')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '59th (13:10)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88th (10:18)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '77th (9:17)',
#  '21.4 Scores': '910th (187 lbs)',
#  'Affiliate': 'Backstage CrossFit',
#  'Age': 30,
#  'Continent': 'Asia',
#  'Country': 'Russian Federation',
#  'First Name': 'Svetlana',
#  'Height': '155 cm ',
#  'Height and Weight': '155 cm | 60 kg',
#  'Last Name': 'Kubyshkina',
#  'Placing': 79,
#  'Points': 1134,
#  'Weight': ' 60 kg',
#  'Weight Lifted': 'Weight lifted: 187 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0e4')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '188th (14:14)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '32nd (9:49)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '11th (8:19)',
#  '21.4 Scores': '905th (187 lbs)',
#  'Affiliate': 'CrossFit Black Five',
#  'Age': 39,
#  'Continent': 'Europe',
#  'Country': 'United Kingdom',
#  'First Name': 'Samantha',
#  'Height': '170 cm ',
#  'Height and Weight': '170 cm | 135 lb',
#  'Last Name': 'Briggs',
#  'Placing': 80,
#  'Points': 1136,
#  'Weight': ' 135 lb',
#  'Weight Lifted': 'Weight lifted: 187 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0e5')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '66th (13:13)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '835th (11:48)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '109th (9:36)',
#  '21.4 Scores': '145th (207 lbs)',
#  'Affiliate': 'CrossFit Omnia',
#  'Age': 30,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Kelly',
#  'Height': '65 in ',
#  'Height and Weight': '65 in | 150 lb',
#  'Last Name': 'Stone',
#  'Placing': 81,
#  'Points': 1155,
#  'Weight': ' 150 lb',
#  'Weight Lifted': 'Weight lifted: 207 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0e6')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '80th (13:25)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '490th (11:20)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '330th (10:43)',
#  '21.4 Scores': '267th (202 lbs)',
#  'Affiliate': 'CrossFit WaterSide',
#  'Age': 33,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Cassidy',
#  'Height': '63 in ',
#  'Height and Weight': '63 in | 140 lb',
#  'Last Name': 'Lance-Mcwherter',
#  'Placing': 82,
#  'Points': 1167,
#  'Weight': ' 140 lb',
#  'Weight Lifted': 'Weight lifted: 202 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0e7')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '92nd (13:31)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '155th (10:36)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '340th (10:44)',
#  '21.4 Scores': '585th (193 lbs)',
#  'Affiliate': 'Caution CrossFit Miami Lakes',
#  'Age': 27,
#  'Continent': 'South America',
#  'Country': 'Venezuela',
#  'First Name': 'Laura',
#  'Height': '67 in ',
#  'Height and Weight': '67 in | 148 lb',
#  'Last Name': 'Gonzalez-Marin',
#  'Placing': 84,
#  'Points': 1172,
#  'Weight': ' 148 lb',
#  'Weight Lifted': 'Weight lifted: 193 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0e8')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '319th (14:47)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '187th (10:42)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '172nd (9:59)',
#  '21.4 Scores': '501st (195 lbs)',
#  'Affiliate': 'Stroud CrossFit',
#  'Age': 30,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Bailey',
#  'Height': '62 in ',
#  'Height and Weight': '62 in | 138 lb',
#  'Last Name': 'Meraviglia',
#  'Placing': 87,
#  'Points': 1179,
#  'Weight': ' 138 lb',
#  'Weight Lifted': 'Weight lifted: 195 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0e9')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '154th (14:00)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '38th (9:55)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '189th (10:03)',
#  '21.4 Scores': '867th (188 lbs)',
#  'Affiliate': 'C23 CrossFit',
#  'Age': 23,
#  'Continent': 'Europe',
#  'Country': 'Sweden',
#  'First Name': 'Ella',
#  'Height': '170 cm ',
#  'Height and Weight': '170 cm | 65 kg',
#  'Last Name': 'Wunger',
#  'Placing': 93,
#  'Points': 1248,
#  'Weight': ' 65 kg',
#  'Weight Lifted': 'Weight lifted: 188 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0ea')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '107th (13:41)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '141st (10:34)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '96th (9:30)',
#  '21.4 Scores': '912th (187 lbs)',
#  'Affiliate': 'CrossFit 10K',
#  'Age': 34,
#  'Continent': 'Europe',
#  'Country': 'Finland',
#  'First Name': 'Emilia',
#  'Height': '165 cm ',
#  'Height and Weight': '165 cm | 150 lb',
#  'Last Name': 'Leppänen',
#  'Placing': 94,
#  'Points': 1256,
#  'Weight': ' 150 lb',
#  'Weight Lifted': 'Weight lifted: 187 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0eb')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '5th (11:14)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '250th (10:53)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '102nd (9:33)',
#  '21.4 Scores': '913th (187 lbs)',
#  'Affiliate': 'C2X CrossFit',
#  'Age': 22,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Alexis',
#  'Height': '65 in ',
#  'Height and Weight': '65 in | 138 lb',
#  'Last Name': 'Raptis',
#  'Placing': 95,
#  'Points': 1270,
#  'Weight': ' 138 lb',
#  'Weight Lifted': 'Weight lifted: 187 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0ec')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '278th (14:38)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '283rd (10:57)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '256th (10:25)',
#  '21.4 Scores': '481st (196 lbs)',
#  'Affiliate': 'JH CrossFit',
#  'Age': 28,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Rachel',
#  'Height': '63 in ',
#  'Height and Weight': '63 in | 130 lb',
#  'Last Name': 'Thibodeaux',
#  'Placing': 97,
#  'Points': 1298,
#  'Weight': ' 130 lb',
#  'Weight Lifted': 'Weight lifted: 196 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0ed')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '253rd (14:32)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '510th (11:23)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '239th (10:21)',
#  '21.4 Scores': '302nd (201 lbs)',
#  'Affiliate': 'CrossFit PSC',
#  'Age': 30,
#  'Continent': 'North America',
#  'Country': 'Canada',
#  'First Name': 'Kaitlyn',
#  'Height': '63 in ',
#  'Height and Weight': '63 in | 150 lb',
#  'Last Name': 'Anapolsky',
#  'Placing': 98,
#  'Points': 1304,
#  'Weight': ' 150 lb',
#  'Weight Lifted': 'Weight lifted: 201 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0ee')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '80th (13:25)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '27th (9:45)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '142nd (9:49)',
#  '21.4 Scores': '1075th (186 lbs)',
#  'Affiliate': 'CrossFit Nottingham',
#  'Age': 25,
#  'Continent': 'Europe',
#  'Country': 'United Kingdom',
#  'First Name': 'Lucy',
#  'Height': '168 cm ',
#  'Height and Weight': '168 cm | 74 kg',
#  'Last Name': 'Campbell',
#  'Placing': 99,
#  'Points': 1324,
#  'Weight': ' 74 kg',
#  'Weight Lifted': 'Weight lifted: 186 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0ef')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '389th (14:58)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '432nd (11:14)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '309th (10:37)',
#  '21.4 Scores': '195th (205 lbs)',
#  'Affiliate': 'CrossFit Avignon',
#  'Age': 31,
#  'Continent': 'Europe',
#  'Country': 'France',
#  'First Name': 'Tatiana',
#  'Height': '157 cm ',
#  'Height and Weight': '157 cm | 63 kg',
#  'Last Name': 'Membré',
#  'Placing': 100,
#  'Points': 1325,
#  'Weight': ' 63 kg',
#  'Weight Lifted': 'Weight lifted: 205 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0f0')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '244th (14:30)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '119th (10:29)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '58th (9:09)',
#  '21.4 Scores': '908th (187 lbs)',
#  'Affiliate': 'CrossFit Invictus',
#  'Age': 24,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Taylor',
#  'Height': '65 in ',
#  'Height and Weight': '65 in | 140 lb',
#  'Last Name': 'Ballek',
#  'Placing': 102,
#  'Points': 1329,
#  'Weight': ' 140 lb',
#  'Weight Lifted': 'Weight lifted: 187 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0f1')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '55th (13:08)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '556th (11:27)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '172nd (9:59)',
#  '21.4 Scores': '584th (193 lbs)',
#  'Affiliate': 'CrossFit Maven',
#  'Age': 20,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Faith',
#  'Height': '63 in ',
#  'Height and Weight': '63 in | 150 lb',
#  'Last Name': 'Ferguson',
#  'Placing': 104,
#  'Points': 1367,
#  'Weight': ' 150 lb',
#  'Weight Lifted': 'Weight lifted: 193 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0f2')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '107th (13:41)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '228th (10:50)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '172nd (9:59)',
#  '21.4 Scores': '866th (188 lbs)',
#  'Affiliate': 'CrossFit Invictus Back Bay',
#  'Age': 29,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Stephanie',
#  'Height': '65 in ',
#  'Height and Weight': '65 in | 150 lb',
#  'Last Name': 'Chung',
#  'Placing': 106,
#  'Points': 1373,
#  'Weight': ' 150 lb',
#  'Weight Lifted': 'Weight lifted: 188 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0f3')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '134th (13:51)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '523rd (11:24)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '502nd (11:20)',
#  '21.4 Scores': '271st (202 lbs)',
#  'Affiliate': 'Derby City CrossFit',
#  'Age': 27,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Lexi',
#  'Height': '62 in ',
#  'Height and Weight': '62 in | 130 lb',
#  'Last Name': 'Colabianchi',
#  'Placing': 109,
#  'Points': 1430,
#  'Weight': ' 130 lb',
#  'Weight Lifted': 'Weight lifted: 202 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0f4')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '211th (14:22)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '199th (10:44)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '309th (10:37)',
#  '21.4 Scores': '713th (190 lbs)',
#  'Affiliate': 'CrossFit Eikestad',
#  'Age': 28,
#  'Continent': 'Africa',
#  'Country': 'South Africa',
#  'First Name': 'Mariska',
#  'Height': '168 cm ',
#  'Height and Weight': '168 cm | 64 kg',
#  'Last Name': 'Smit',
#  'Placing': 110,
#  'Points': 1432,
#  'Weight': ' 64 kg',
#  'Weight Lifted': 'Weight lifted: 190 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0f5')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '171st (14:07)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '228th (10:50)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '120th (9:41)',
#  '21.4 Scores': '915th (187 lbs)',
#  'Affiliate': 'CrossFit Grillen',
#  'Age': 22,
#  'Continent': 'Europe',
#  'Country': 'France',
#  'First Name': 'Claudia',
#  'Height': '160 cm ',
#  'Height and Weight': '160 cm | 60 kg',
#  'Last Name': 'Gluck',
#  'Placing': 111,
#  'Points': 1434,
#  'Weight': ' 60 kg',
#  'Weight Lifted': 'Weight lifted: 187 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0f6')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '186th (14:13)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '228th (10:50)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '440th (11:09)',
#  '21.4 Scores': '590th (193 lbs)',
#  'Affiliate': 'Kawi CrossFit',
#  'Age': 29,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Jordan',
#  'Height': '66 in ',
#  'Height and Weight': '66 in | 140 lb',
#  'Last Name': 'Adcock',
#  'Placing': 112,
#  'Points': 1444,
#  'Weight': ' 140 lb',
#  'Weight Lifted': 'Weight lifted: 193 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0f7')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '225th (14:26)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '115th (10:28)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '286th (10:31)',
#  '21.4 Scores': '849th (189 lbs)',
#  'Affiliate': 'CrossFit Project Bayside',
#  'Age': 29,
#  'Continent': 'Oceania',
#  'Country': 'New Zealand',
#  'First Name': 'Aimee',
#  'Height': '163 cm ',
#  'Height and Weight': '163 cm | 66 kg',
#  'Last Name': 'Tawhai',
#  'Placing': 115,
#  'Points': 1475,
#  'Weight': ' 66 kg',
#  'Weight Lifted': 'Weight lifted: 189 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0f8')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '191st (14:17)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '370th (11:07)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '340th (10:44)',
#  '21.4 Scores': '585th (193 lbs)',
#  'Affiliate': 'CrossFit Athletic Academy',
#  'Age': 29,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Brittany',
#  'Height': '63 in ',
#  'Height and Weight': '63 in | 150 lb',
#  'Last Name': 'Marella',
#  'Placing': 116,
#  'Points': 1486,
#  'Weight': ' 150 lb',
#  'Weight Lifted': 'Weight lifted: 193 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0f9')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '225th (14:26)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '395th (11:10)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '345th (10:45)',
#  '21.4 Scores': '577th (194 lbs)',
#  'Affiliate': 'CrossFit Training Yard',
#  'Age': 40,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Rebecca',
#  'Height': '69 in ',
#  'Height and Weight': '69 in | 152 lb',
#  'Last Name': 'Voigt Miller',
#  'Placing': 120,
#  'Points': 1542,
#  'Weight': ' 152 lb',
#  'Weight Lifted': 'Weight lifted: 194 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0fa')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '75th (13:21)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '483rd (11:19)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '411th (11:01)',
#  '21.4 Scores': '589th (193 lbs)',
#  'Affiliate': 'CrossFit Mayflower',
#  'Age': 28,
#  'Continent': 'Europe',
#  'Country': 'United Kingdom',
#  'First Name': 'Janie',
#  'Height': '158 cm ',
#  'Height and Weight': '158 cm | 63 kg',
#  'Last Name': 'Garratt',
#  'Placing': 122,
#  'Points': 1558,
#  'Weight': ' 63 kg',
#  'Weight Lifted': 'Weight lifted: 193 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0fb')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '98th (13:34)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '456th (11:17)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '155th (9:55)',
#  '21.4 Scores': '919th (187 lbs)',
#  'Affiliate': 'CrossFit Train 97333',
#  'Age': 43,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Joey',
#  'Height': '61 in ',
#  'Height and Weight': '61 in | 125 lb',
#  'Last Name': 'Kimdon',
#  'Placing': 126,
#  'Points': 1628,
#  'Weight': ' 125 lb',
#  'Weight Lifted': 'Weight lifted: 187 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0fc')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '191st (14:17)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '646th (11:33)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '291st (10:32)',
#  '21.4 Scores': '505th (195 lbs)',
#  'Affiliate': 'Kingbull CrossFit',
#  'Age': 28,
#  'Continent': 'South America',
#  'Country': 'Paraguay',
#  'First Name': 'Carol',
#  'Height': '157 cm ',
#  'Height and Weight': '157 cm | 57 kg',
#  'Last Name': 'Colling',
#  'Placing': 127,
#  'Points': 1633,
#  'Weight': ' 57 kg',
#  'Weight Lifted': 'Weight lifted: 195 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0fd')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '110th (13:43)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '853rd (11:49)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '23rd (8:45)',
#  '21.4 Scores': '682nd (191 lbs)',
#  'Affiliate': 'CrossFit Bolt',
#  'Age': 21,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Rebecca',
#  'Height': '62 in ',
#  'Height and Weight': '62 in | 125 lb',
#  'Last Name': 'Fuselier',
#  'Placing': 133,
#  'Points': 1668,
#  'Weight': ' 125 lb',
#  'Weight Lifted': 'Weight lifted: 191 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0fe')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '296th (14:42)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '958th (11:55)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '434th (11:07)',
#  '21.4 Scores': '19th (225 lbs)',
#  'Affiliate': 'CrossFit Crosscheck',
#  'Age': 38,
#  'Continent': 'North America',
#  'Country': 'Canada',
#  'First Name': 'Meg',
#  'Height': '177 cm ',
#  'Height and Weight': '177 cm | 160 lb',
#  'Last Name': 'Garrett',
#  'Placing': 138,
#  'Points': 1707,
#  'Weight': ' 160 lb',
#  'Weight Lifted': 'Weight lifted: 225 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac0ff')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '196th (14:18)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '149th (10:35)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '533rd (11:25)',
#  '21.4 Scores': '870th (188 lbs)',
#  'Affiliate': 'CrossFit Bergisch Gladbach',
#  'Age': 28,
#  'Continent': 'Europe',
#  'Country': 'Germany',
#  'First Name': 'Lidia',
#  'Height': '168 cm ',
#  'Height and Weight': '168 cm | 63 kg',
# ...
#  '21.2 Scores': '88726th (14:17 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '76529th (6:14 - f)',
#  '21.4 Scores': '79581st (35 lbs - f)',
#  'Affiliate': 'CrossFit Piraeus',
#  'Age': 44,
#  'Continent': 'Europe',
#  'Country': 'Greece',
#  'First Name': 'Afroditi',
#  'Height': '165 cm ',
#  'Height and Weight': '165 cm | 62 kg',
#  'Last Name': 'Fragkouli',
#  'Placing': 92398,
#  'Points': 336018,
#  'Weight': ' 62 kg',
#  'Weight Lifted': 'Weight lifted: 35 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac278')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91596th (13:46 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88066th (9:21 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '77882nd (8:07 - f)',
#  '21.4 Scores': '78557th (66 lbs - f)',
#  'Affiliate': 'Ikigai CrossFit',
#  'Age': 43,
#  'Continent': 'Europe',
#  'Country': 'Germany',
#  'First Name': 'Yvonne',
#  'Height': '169 cm ',
#  'Height and Weight': '169 cm | 53 kg',
#  'Last Name': 'Alt',
#  'Placing': 92431,
#  'Points': 336101,
#  'Weight': ' 53 kg',
#  'Weight Lifted': 'Weight lifted: 66 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac279')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91422nd (12:46 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88642nd (13:47 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '76993rd (6:59 - f)',
#  '21.4 Scores': '79266th (51 lbs - f)',
#  'Affiliate': 'CrossFit Heilbronn',
#  'Age': 46,
#  'Continent': 'Europe',
#  'Country': 'Germany',
#  'First Name': 'Elke',
#  'Height': '160 cm ',
#  'Height and Weight': '160 cm | 58 kg',
#  'Last Name': 'Fuhrmann',
#  'Placing': 92510,
#  'Points': 336323,
#  'Weight': ' 58 kg',
#  'Weight Lifted': 'Weight lifted: 51 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac27a')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91526th (13:23 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88593rd (13:28 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '76929th (6:54 - f)',
#  '21.4 Scores': '79343rd (48 lbs - f)',
#  'Affiliate': 'CrossFit Leyland',
#  'Age': 26,
#  'Continent': 'Europe',
#  'Country': 'United Kingdom',
#  'First Name': 'Lucy',
#  'Height': '160 in ',
#  'Height and Weight': '160 in | 56 kg',
#  'Last Name': 'Sirvinskas',
#  'Placing': 92535,
#  'Points': 336391,
#  'Weight': ' 56 kg',
#  'Weight Lifted': 'Weight lifted: 48 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac27b')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91254th (11:14 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88068th (9:22 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '77246th (7:20 - f)',
#  '21.4 Scores': '79837th (13 lbs - f)',
#  'Affiliate': 'CrossFit Trnava',
#  'Age': 29,
#  'Continent': 'Europe',
#  'Country': 'Slovakia',
#  'First Name': 'Maria',
#  'Height': '160 cm ',
#  'Height and Weight': '160 cm | 50 kg',
#  'Last Name': 'Papankova',
#  'Placing': 92541,
#  'Points': 336405,
#  'Weight': ' 50 kg',
#  'Weight Lifted': 'Weight lifted: 13 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac27c')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91371st (12:22 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88667th (13:55 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '77347th (7:27 - f)',
#  '21.4 Scores': '79061st (55 lbs - f)',
#  'Affiliate': 'St. Helena CrossFit',
#  'Age': 51,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Crissy',
#  'Height': '62 in ',
#  'Height and Weight': '62 in | 128 lb',
#  'Last Name': 'Broyles',
#  'Placing': 92557,
#  'Points': 336446,
#  'Weight': ' 128 lb',
#  'Weight Lifted': 'Weight lifted: 55 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac27d')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91819th (14:51 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88466th (12:39 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '77932nd (8:10 - f)',
#  '21.4 Scores': '78284th (71 lbs - f)',
#  'Affiliate': 'CrossFit Leyland',
#  'Age': 33,
#  'Continent': 'Europe',
#  'Country': 'United Kingdom',
#  'First Name': 'Sally',
#  'Height': '62 in ',
#  'Height and Weight': '62 in | 175 lb',
#  'Last Name': 'Foster',
#  'Placing': 92580,
#  'Points': 336501,
#  'Weight': ' 175 lb',
#  'Weight Lifted': 'Weight lifted: 71 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac27e')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91334th (12:03 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88378th (12:05 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '78245th (8:36 - f)',
#  '21.4 Scores': '78568th (66 lbs - f)',
#  'Affiliate': 'CrossFit Thurles',
#  'Age': 43,
#  'Continent': 'Europe',
#  'Country': 'Ireland',
#  'First Name': 'Brí',
#  'Height': '175 cm ',
#  'Height and Weight': '175 cm | 67 kg',
#  'Last Name': 'Greene',
#  'Placing': 92597,
#  'Points': 336525,
#  'Weight': ' 67 kg',
#  'Weight Lifted': 'Weight lifted: 66 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac27f')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91758th (14:35 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88736th (14:20 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '76651st (6:28 - f)',
#  '21.4 Scores': '79583rd (35 lbs - f)',
#  'Affiliate': 'CrossFit Flower Mound',
#  'Age': 48,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Karen',
#  'Height': '64 in ',
#  'Height and Weight': '64 in | 138 lb',
#  'Last Name': 'Brown',
#  'Placing': 92683,
#  'Points': 336728,
#  'Weight': ' 138 lb',
#  'Weight Lifted': 'Weight lifted: 35 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac280')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91826th (14:52 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88620th (13:39 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '77013th (7:01 - f)',
#  '21.4 Scores': '79373rd (45 lbs - f)',
#  'Affiliate': 'FFD CrossFit',
#  'Age': 28,
#  'Continent': 'South America',
#  'Country': 'Brazil',
#  'First Name': 'Natalia',
#  'Height': '174 cm ',
#  'Height and Weight': '174 cm | 58 kg',
#  'Last Name': 'Albuquerque',
#  'Placing': 92713,
#  'Points': 336832,
#  'Weight': ' 58 kg',
#  'Weight Lifted': 'Weight lifted: 45 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac281')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91530th (13:25 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88402nd (12:13 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '77136th (7:11 - f)',
#  '21.4 Scores': '79795th (17 lbs - f)',
#  'Affiliate': 'CrossFit Dire Wolf',
#  'Age': 34,
#  'Continent': 'Europe',
#  'Country': 'United Kingdom',
#  'First Name': 'Jamie',
#  'Height': '162 cm ',
#  'Height and Weight': '162 cm | 56 kg',
#  'Last Name': 'King',
#  'Placing': 92728,
#  'Points': 336863,
#  'Weight': ' 56 kg',
#  'Weight Lifted': 'Weight lifted: 17 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac282')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91417th (12:41 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88593rd (13:28 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '77399th (7:32 - f)',
#  '21.4 Scores': '79592nd (35 lbs - f)',
#  'Affiliate': 'CrossFit Altrincham',
#  'Age': 40,
#  'Continent': 'Europe',
#  'Country': 'United Kingdom',
#  'First Name': 'Ailsa',
#  'Height': '170 cm ',
#  'Height and Weight': '170 cm | 136 lb',
#  'Last Name': 'Birchenough',
#  'Placing': 92773,
#  'Points': 337001,
#  'Weight': ' 136 lb',
#  'Weight Lifted': 'Weight lifted: 35 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac283')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91472nd (13:04 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88791st (14:38 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '77903rd (8:08 - f)',
#  '21.4 Scores': '78903rd (60 lbs - f)',
#  'Affiliate': 'CrossFit Actuate',
#  'Age': 21,
#  'Continent': 'North America',
#  'Country': 'Canada',
#  'First Name': 'Lauren',
#  'Height': '62 in ',
#  'Height and Weight': '62 in | 116 lb',
#  'Last Name': 'Kaiser',
#  'Placing': 92792,
#  'Points': 337069,
#  'Weight': ' 116 lb',
#  'Weight Lifted': 'Weight lifted: 60 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac284')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91813th (14:49 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88185th (10:36 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '77838th (8:04 - f)',
#  '21.4 Scores': '79290th (50 lbs - f)',
#  'Affiliate': 'True Spirit CrossFit',
#  'Age': 49,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Heidi',
#  'Height': '64 in ',
#  'Height and Weight': '64 in | 190 lb',
#  'Last Name': 'Maxwell',
#  'Placing': 92817,
#  'Points': 337126,
#  'Weight': ' 190 lb',
#  'Weight Lifted': 'Weight lifted: 50 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac285')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91495th (13:11 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88728th (14:18 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '79046th (9:53 - f)',
#  '21.4 Scores': '77934th (77 lbs - f)',
#  'Affiliate': 'CrossFit Cachoeiro',
#  'Age': 38,
#  'Continent': 'South America',
#  'Country': 'Brazil',
#  'First Name': 'Alessandra',
#  'Height': '159 cm ',
#  'Height and Weight': '159 cm | 59 kg',
#  'Last Name': 'Pereira',
#  'Placing': 92846,
#  'Points': 337203,
#  'Weight': ' 59 kg',
#  'Weight Lifted': 'Weight lifted: 77 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac286')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91200th (10:20 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '89212th (17:18 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '78329th (8:43 - f)',
#  '21.4 Scores': '78921st (60 lbs - f)',
#  'Affiliate': 'Iron Springs CrossFit',
#  'Age': 54,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Brandi',
#  'Height': '63 in ',
#  'Height and Weight': '63 in | 135 lb',
#  'Last Name': 'Wood',
#  'Placing': 93016,
#  'Points': 337662,
#  'Weight': ' 135 lb',
#  'Weight Lifted': 'Weight lifted: 60 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac287')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91530th (13:25 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88836th (14:53 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '78116th (8:25 - f)',
#  '21.4 Scores': '79651st (33 lbs - f)',
#  'Affiliate': 'CrossFit Proton',
#  'Age': 39,
#  'Continent': 'Europe',
#  'Country': 'Slovakia',
#  'First Name': 'Veronika',
#  'Height': '180 in ',
#  'Height and Weight': '180 in | 68 kg',
#  'Last Name': 'Kassayová',
#  'Placing': 93184,
#  'Points': 338133,
#  'Weight': ' 68 kg',
#  'Weight Lifted': 'Weight lifted: 33 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac288')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91162nd (9:10 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '89157th (16:51 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '79990th (13:38 - f)',
#  '21.4 Scores': '78177th (75 lbs - f)',
#  'Affiliate': 'Rose City CrossFit',
#  'Age': 36,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Sophia',
#  'Height': '64 in ',
#  'Height and Weight': '64 in | 142 lb',
#  'Last Name': 'Thomas',
#  'Placing': 93330,
#  'Points': 338486,
#  'Weight': ' 142 lb',
#  'Weight Lifted': 'Weight lifted: 75 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac289')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91409th (12:36 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88695th (14:05 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '78599th (9:05 - f)',
#  '21.4 Scores': '79799th (17 lbs - f)',
#  'Affiliate': 'CrossFit Green',
#  'Age': 32,
#  'Continent': 'North America',
#  'Country': 'Canada',
#  'First Name': 'Kimberly',
#  'Height': '65 in ',
#  'Height and Weight': '65 in | 150 lb',
#  'Last Name': 'Wong',
#  'Placing': 93335,
#  'Points': 338502,
#  'Weight': ' 150 lb',
#  'Weight Lifted': 'Weight lifted: 17 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac28a')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91515th (13:18 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88575th (13:19 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '78821st (9:27 - f)',
#  '21.4 Scores': '79754th (22 lbs - f)',
#  'Affiliate': 'CrossFit 4504',
#  'Age': 36,
#  'Continent': 'Oceania',
#  'Country': 'Australia',
#  'First Name': 'Mandy-Leigh',
#  'Height': '159 cm ',
#  'Height and Weight': '159 cm | 63 kg',
#  'Last Name': 'Hackart',
#  'Placing': 93409,
#  'Points': 338665,
#  'Weight': ' 63 kg',
#  'Weight Lifted': 'Weight lifted: 22 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac28b')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91602nd (13:47 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88404th (12:14 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '79031st (9:51 - f)',
#  '21.4 Scores': '79655th (33 lbs - f)',
#  'Affiliate': 'CrossFit Leyland',
#  'Age': 33,
#  'Continent': 'Europe',
#  'Country': 'United Kingdom',
#  'First Name': 'Charlotte',
#  'Height': '164 cm ',
#  'Height and Weight': '164 cm | 66 kg',
#  'Last Name': 'Cox',
#  'Placing': 93427,
#  'Points': 338692,
#  'Weight': ' 66 kg',
#  'Weight Lifted': 'Weight lifted: 33 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac28c')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91588th (13:43 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88323rd (11:41 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '79003rd (9:48 - f)',
#  '21.4 Scores': '79936th (1 lbs - f)',
#  'Affiliate': 'CrossFit Rhein-Neckar',
#  'Age': 46,
#  'Continent': 'Europe',
#  'Country': 'Germany',
#  'First Name': 'Birgit',
#  'Height': '173 cm ',
#  'Height and Weight': '173 cm | 67 kg',
#  'Last Name': 'Baldauf',
#  'Placing': 93497,
#  'Points': 338850,
#  'Weight': ' 67 kg',
#  'Weight Lifted': 'Weight lifted: 1 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac28d')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91165th (9:23 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88152nd (10:24 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '79945th (13:14 - f)',
#  '21.4 Scores': '79630th (35 lbs - f)',
#  'Affiliate': 'CrossFit Stony Brook',
#  'Age': 34,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Victoria',
#  'Height': '69 in ',
#  'Height and Weight': '69 in | 145 lb',
#  'Last Name': 'Michel',
#  'Placing': 93516,
#  'Points': 338892,
#  'Weight': ' 145 lb',
#  'Weight Lifted': 'Weight lifted: 35 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac28e')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91360th (12:17 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '89232nd (17:28 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '79392nd (10:40 - f)',
#  '21.4 Scores': '79845th (13 lbs - f)',
#  'Affiliate': 'MKB CrossFit',
#  'Age': 35,
#  'Continent': 'Europe',
#  'Country': 'France',
#  'First Name': 'Laetitia',
#  'Height': '170 cm ',
#  'Height and Weight': '170 cm | 69 kg',
#  'Last Name': 'Decraene',
#  'Placing': 93907,
#  'Points': 339829,
#  'Weight': ' 69 kg',
#  'Weight Lifted': 'Weight lifted: 13 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac28f')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91749th (14:32 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88558th (13:14 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '79979th (13:31 - f)',
#  '21.4 Scores': '79809th (16 lbs - f)',
#  'Affiliate': 'CrossFit Tartu',
#  'Age': 37,
#  'Continent': 'Europe',
#  'Country': 'Estonia',
#  'First Name': 'Sille',
#  'Height': '174 cm ',
#  'Height and Weight': '174 cm | 68 kg',
#  'Last Name': 'Vaiksaar',
#  'Placing': 93996,
#  'Points': 340095,
#  'Weight': ' 68 kg',
#  'Weight Lifted': 'Weight lifted: 16 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac290')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91725th (14:25 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88988th (15:49 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '79071st (9:56 - f)',
#  '21.4 Scores': '84511th (0 lbs - f)',
#  'Affiliate': 'Wild Horizons CrossFit',
#  'Age': 54,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Maria',
#  'Height': '63 in ',
#  'Height and Weight': '63 in | 157 lb',
#  'Last Name': 'Wheeler',
#  'Placing': 95263,
#  'Points': 344295,
#  'Weight': ' 157 lb',
#  'Weight Lifted': 'Weight lifted: 0 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac291')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91795th (14:44 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88760th (14:29 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '78698th (9:14 - f)',
#  '21.4 Scores': '96950th (0 lbs - f)',
#  'Affiliate': 'Badger CrossFit',
#  'Age': 17,
#  'Continent': 'North America',
#  'Country': 'United States',
#  'First Name': 'Stella',
#  'Height': '67 in ',
#  'Height and Weight': '67 in | 140 lb',
#  'Last Name': 'Richards',
#  'Placing': 100421,
#  'Points': 356203,
#  'Weight': ' 140 lb',
#  'Weight Lifted': 'Weight lifted: 0 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac292')}
# {'21.1 Reps': 605,
#  '21.1 Scores': '91650th (14:04 - f)',
#  '21.2 Reps': 225,
#  '21.2 Scores': '88356th (11:55 - f)',
#  '21.3 Reps': 180,
#  '21.3 Scores': '76824th (6:45 - f)',
#  '21.4 Scores': '104507th (0 lbs - f)',
#  'Affiliate': 'CW1 CrossFit',
#  'Age': 35,
#  'Continent': 'Europe',
#  'Country': 'United Kingdom',
#  'First Name': 'Sarah',
#  'Height': '168 cm ',
#  'Height and Weight': '168 cm | 59 kg',
#  'Last Name': 'Carter',
#  'Placing': 102710,
#  'Points': 361337,
#  'Weight': ' 59 kg',
#  'Weight Lifted': 'Weight lifted: 0 lbs.',
#  '_id': ObjectId('643f1ac9000864d490eac293')}
